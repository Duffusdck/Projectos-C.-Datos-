# %% [markdown]
# ##Instalacion de librerias

# %% [markdown]
# Se instala la libreria sqlite para poder trabajar con bases de datos

# %%
# %%shell
# sudo apt-get install sqlite3

# %% [markdown]
# ##Crear la base de datos y una tabla de inventario

# %% [markdown]
# El siguiente codigo crea una base de datos llamada "productos.db" y un cursor "c" para facilitar la conexion y ejecucion de comandos sql.

# %%
import sqlite3
import random

# Crear la base de datos con SQlite
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %% [markdown]
# Se crea una tabla en la base de datos con 8 atributos

# %%
# Crear una tabla llamada 'inventario'
c.execute('''
CREATE TABLE inventario (
    id INTEGER PRIMARY KEY,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)
''')

# %% [markdown]
# Se crea una funcion para automatizar la creacion de datos para la tabla. Para que los datos no sean iguales se hace uso de random.

# %%
# Generar datos de ejemplo para la tabla
def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

# Insertar 1000 productos en la tabla
productos = [generar_producto(i + 1) for i in range(10000)]
c.executemany('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', productos)

# Guardar cambios y cerrar la conexión
conn.commit()
conn.close()

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# ##Consulta para mostrar todos los productos creados

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# (1, 'Objeto1', 'Jardín', 420.37, 62, 'Proveedor1', '2023-09-17', 'Almacén C')
# (2, 'Producto2', 'Moda', 348.83, 42, 'Proveedor3', '2023-02-21', 'Almacén C')
# (3, 'Artículo3', 'Moda', 308.65, 76, 'Proveedor2', '2023-03-25', 'Almacén B')
# (4, 'Objeto4', 'Hogar', 201.76, 91, 'Proveedor2', '2023-11-21', 'Almacén C')
# (5, 'Objeto5', 'Hogar', 235.66, 85, 'Proveedor1', '2023-10-19', 'Almacén A')
# (6, 'Objeto6', 'Electrónica', 304.85, 24, 'Proveedor3', '2023-03-23', 'Almacén C')
# (7, 'Artículo7', 'Moda', 52.63, 27, 'Proveedor1', '2023-11-05', 'Almacén B')
# (8, 'Objeto8', 'Electrónica', 421.48, 86, 'Proveedor2', '2023-12-01', 'Almacén C')
# (9, 'Producto9', 'Electrónica', 70.5, 44, 'Proveedor1', '2023-04-26', 'Almacén A')
# (10, 'Objeto10', 'Moda', 381.07, 80, 'Proveedor1', '2023-01-22', 'Almacén B')
# (11, 'Objeto11', 'Jardín', 385.79, 32, 'Proveedor2', '2023-09-10', 'Almacén B')
# (12, 'Producto12', 'Electrónica', 273.98, 12, 'Proveedor2', '2023-05-27', 'Almacén C')
# (13, 'Artículo13', 'Moda', 339.6, 17, 'Proveedor1', '2023-05-03', 'Almacén C')
# (14, 'Artículo14', 'Hogar', 122.05, 84, 'Proveedor2', '2023-07-20', 'Almacén A')
# (15, 'Artículo15', 'Electrónica', 432.01, 35, 'Proveedor1', '2023-12-04', 'Almacén C')
# (16, 'Artículo16', 'Jardín', 462.53, 6, 'Proveedor2', '2023-11-23', 'Almacén A')
# (17, 'Producto17', 'Moda', 426.03, 90, 'Proveedor2', '2023-08-22', 'Almacén C')
# (18, 'Artículo18', 'Moda', 189.07, 43, 'Proveedor1', '2023-06-24', 'Almacén A')
# (19, 'Producto19', 'Hogar', 139.65, 40, 'Proveedor3', '2023-02-15', 'Almacén A')
# (20, 'Objeto20', 'Moda', 381.02, 56, 'Proveedor2', '2023-02-26', 'Almacén C')
# (21, 'Objeto21', 'Moda', 293.24, 76, 'Proveedor1', '2023-10-24', 'Almacén C')
# (22, 'Producto22', 'Moda', 196.2, 62, 'Proveedor1', '2023-02-25', 'Almacén C')
# (23, 'Objeto23', 'Electrónica', 489.34, 73, 'Proveedor3', '2023-11-26', 'Almacén A')
# (24, 'Producto24', 'Moda', 45.96, 60, 'Proveedor3', '2023-02-02', 'Almacén C')
# (25, 'Producto25', 'Jardín', 293.71, 64, 'Proveedor2', '2023-11-07', 'Almacén B')
# (26, 'Objeto26', 'Jardín', 352.67, 86, 'Proveedor2', '2023-12-23', 'Almacén C')
# (27, 'Artículo27', 'Deportes', 274.46, 19, 'Proveedor2', '2023-12-28', 'Almacén B')
# (28, 'Producto28', 'Jardín', 179.9, 99, 'Proveedor1', '2023-06-23', 'Almacén B')
# (29, 'Producto29', 'Deportes', 90.54, 64, 'Proveedor3', '2023-07-20', 'Almacén A')
# (30, 'Producto30', 'Hogar', 344.13, 48, 'Proveedor1', '2023-03-04', 'Almacén C')
# (31, 'Objeto31', 'Deportes', 498.32, 60, 'Proveedor3', '2023-07-12', 'Almacén C')
# (32, 'Producto32', 'Jardín', 33.7, 68, 'Proveedor2', '2023-10-19', 'Almacén B')
# (33, 'Artículo33', 'Jardín', 273.31, 25, 'Proveedor2', '2023-05-15', 'Almacén B')
# (34, 'Artículo34', 'Electrónica', 40.17, 84, 'Proveedor2', '2023-02-24', 'Almacén C')
# (35, 'Producto35', 'Electrónica', 138.56, 24, 'Proveedor3', '2023-12-08', 'Almacén A')
# (36, 'Producto36', 'Moda', 422.78, 7, 'Proveedor1', '2023-05-07', 'Almacén A')
# (37, 'Producto37', 'Moda', 277.77, 84, 'Proveedor1', '2023-07-08', 'Almacén B')
# (38, 'Producto38', 'Hogar', 247, 59, 'Proveedor2', '2023-06-16', 'Almacén C')
# (39, 'Producto39', 'Jardín', 137.96, 84, 'Proveedor1', '2023-03-01', 'Almacén C')
# (40, 'Objeto40', 'Moda', 417.91, 1, 'Proveedor2', '2023-03-12', 'Almacén A')
# (41, 'Producto41', 'Electrónica', 63.14, 61, 'Proveedor2', '2023-06-09', 'Almacén C')
# (42, 'Producto42', 'Hogar', 397.09, 52, 'Proveedor1', '2023-07-27', 'Almacén A')
# (43, 'Producto43', 'Electrónica', 304.69, 82, 'Proveedor1', '2023-03-20', 'Almacén A')
# (44, 'Objeto44', 'Moda', 442.59, 51, 'Proveedor1', '2023-08-12', 'Almacén C')
# (45, 'Producto45', 'Moda', 435.74, 23, 'Proveedor3', '2023-04-22', 'Almacén C')
# (46, 'Artículo46', 'Electrónica', 299.36, 4, 'Proveedor3', '2023-10-09', 'Almacén C')
# (47, 'Artículo47', 'Jardín', 84.7, 55, 'Proveedor2', '2023-10-08', 'Almacén A')
# (48, 'Objeto48', 'Electrónica', 84.59, 50, 'Proveedor1', '2023-05-10', 'Almacén A')
# (49, 'Objeto49', 'Deportes', 380.18, 49, 'Proveedor3', '2023-07-24', 'Almacén C')
# (50, 'Objeto50', 'Electrónica', 112.67, 16, 'Proveedor1', '2023-12-12', 'Almacén C')
# (51, 'Producto51', 'Jardín', 495.95, 73, 'Proveedor1', '2023-04-17', 'Almacén A')
# (52, 'Producto52', 'Jardín', 373.16, 29, 'Proveedor2', '2023-01-16', 'Almacén A')
# (53, 'Artículo53', 'Hogar', 414.6, 75, 'Proveedor2', '2023-04-05', 'Almacén B')
# (54, 'Artículo54', 'Deportes', 173.34, 53, 'Proveedor1', '2023-07-03', 'Almacén C')
# (55, 'Artículo55', 'Deportes', 79.09, 28, 'Proveedor2', '2023-11-22', 'Almacén B')
# (56, 'Objeto56', 'Electrónica', 316.48, 19, 'Proveedor3', '2023-10-11', 'Almacén B')
# (57, 'Producto57', 'Deportes', 490.78, 58, 'Proveedor3', '2023-12-24', 'Almacén C')
# (58, 'Producto58', 'Electrónica', 260.84, 24, 'Proveedor2', '2023-10-18', 'Almacén A')
# (59, 'Artículo59', 'Deportes', 250.29, 25, 'Proveedor3', '2023-12-26', 'Almacén C')
# (60, 'Objeto60', 'Jardín', 277.25, 4, 'Proveedor1', '2023-01-09', 'Almacén C')
# (61, 'Producto61', 'Hogar', 436.53, 18, 'Proveedor3', '2023-11-28', 'Almacén A')
# (62, 'Producto62', 'Deportes', 449.78, 24, 'Proveedor3', '2023-04-28', 'Almacén C')
# (63, 'Producto63', 'Moda', 325.43, 93, 'Proveedor2', '2023-10-23', 'Almacén A')
# (64, 'Producto64', 'Electrónica', 347.29, 97, 'Proveedor3', '2023-11-24', 'Almacén A')
# (65, 'Artículo65', 'Moda', 328.83, 68, 'Proveedor2', '2023-07-28', 'Almacén A')
# (66, 'Artículo66', 'Jardín', 295.23, 96, 'Proveedor3', '2023-12-05', 'Almacén C')
# (67, 'Artículo67', 'Moda', 49.35, 7, 'Proveedor2', '2023-04-28', 'Almacén B')
# (68, 'Producto68', 'Hogar', 369.19, 18, 'Proveedor2', '2023-02-11', 'Almacén B')
# (69, 'Objeto69', 'Jardín', 235.75, 11, 'Proveedor2', '2023-06-24', 'Almacén C')
# (70, 'Producto70', 'Moda', 53.21, 75, 'Proveedor3', '2023-09-25', 'Almacén A')
# (71, 'Artículo71', 'Moda', 436.76, 50, 'Proveedor1', '2023-08-05', 'Almacén A')
# (72, 'Artículo72', 'Moda', 165.39, 27, 'Proveedor2', '2023-12-16', 'Almacén B')
# (73, 'Artículo73', 'Electrónica', 380.25, 80, 'Proveedor1', '2023-08-28', 'Almacén A')
# (74, 'Objeto74', 'Deportes', 290.68, 86, 'Proveedor2', '2023-02-09', 'Almacén A')
# (75, 'Artículo75', 'Moda', 185.4, 51, 'Proveedor2', '2023-07-25', 'Almacén A')
# (76, 'Producto76', 'Jardín', 416.02, 18, 'Proveedor1', '2023-11-12', 'Almacén B')
# (77, 'Artículo77', 'Deportes', 197.17, 78, 'Proveedor2', '2023-12-12', 'Almacén C')
# (78, 'Artículo78', 'Moda', 471.47, 73, 'Proveedor3', '2023-04-11', 'Almacén B')
# (79, 'Objeto79', 'Moda', 450.55, 55, 'Proveedor2', '2023-11-21', 'Almacén B')
# (80, 'Artículo80', 'Deportes', 54.51, 29, 'Proveedor1', '2023-10-28', 'Almacén A')
# (81, 'Producto81', 'Electrónica', 384.12, 29, 'Proveedor3', '2023-05-24', 'Almacén A')
# (82, 'Objeto82', 'Jardín', 85.66, 1, 'Proveedor1', '2023-08-23', 'Almacén A')
# (83, 'Objeto83', 'Moda', 456.05, 16, 'Proveedor1', '2023-11-05', 'Almacén A')
# (84, 'Producto84', 'Jardín', 25.37, 69, 'Proveedor1', '2023-01-16', 'Almacén A')
# (85, 'Artículo85', 'Moda', 20.83, 6, 'Proveedor3', '2023-05-10', 'Almacén B')
# (86, 'Objeto86', 'Moda', 451.74, 7, 'Proveedor1', '2023-11-13', 'Almacén C')
# (87, 'Producto87', 'Hogar', 173.54, 77, 'Proveedor2', '2023-12-19', 'Almacén B')
# (88, 'Producto88', 'Deportes', 215.55, 4, 'Proveedor1', '2023-04-09', 'Almacén B')
# (89, 'Producto89', 'Moda', 169.05, 88, 'Proveedor3', '2023-06-18', 'Almacén C')
# (90, 'Producto90', 'Deportes', 25.08, 12, 'Proveedor2', '2023-05-09', 'Almacén C')
# (91, 'Producto91', 'Jardín', 422.56, 49, 'Proveedor3', '2023-09-04', 'Almacén A')
# (92, 'Producto92', 'Electrónica', 48.58, 9, 'Proveedor2', '2023-09-01', 'Almacén C')
# (93, 'Objeto93', 'Hogar', 222.63, 22, 'Proveedor3', '2023-09-19', 'Almacén C')
# (94, 'Producto94', 'Jardín', 446.25, 63, 'Proveedor2', '2023-05-28', 'Almacén B')
# (95, 'Artículo95', 'Jardín', 39.37, 81, 'Proveedor2', '2023-03-24', 'Almacén B')
# (96, 'Objeto96', 'Jardín', 98.44, 92, 'Proveedor1', '2023-10-02', 'Almacén B')
# (97, 'Objeto97', 'Moda', 322.6, 80, 'Proveedor2', '2023-12-10', 'Almacén B')
# (98, 'Artículo98', 'Hogar', 414.24, 7, 'Proveedor2', '2023-12-24', 'Almacén C')
# (99, 'Artículo99', 'Deportes', 64.38, 52, 'Proveedor1', '2023-01-21', 'Almacén B')
# (100, 'Artículo100', 'Hogar', 432.61, 22, 'Proveedor2', '2023-07-23', 'Almacén B')
# (101, 'Producto101', 'Electrónica', 43.29, 27, 'Proveedor3', '2023-09-28', 'Almacén B')
# (102, 'Artículo102', 'Hogar', 106.41, 73, 'Proveedor3', '2023-03-24', 'Almacén B')
# (103, 'Producto103', 'Hogar', 411.55, 12, 'Proveedor3', '2023-12-13', 'Almacén B')
# (104, 'Producto104', 'Moda', 426.08, 17, 'Proveedor1', '2023-08-04', 'Almacén A')
# (105, 'Producto105', 'Electrónica', 406.52, 1, 'Proveedor2', '2023-04-08', 'Almacén B')
# (106, 'Objeto106', 'Jardín', 50.74, 46, 'Proveedor1', '2023-02-26', 'Almacén B')
# (107, 'Objeto107', 'Jardín', 336.98, 53, 'Proveedor1', '2023-04-08', 'Almacén C')
# (108, 'Objeto108', 'Deportes', 123.05, 11, 'Proveedor3', '2023-10-19', 'Almacén A')
# (109, 'Producto109', 'Electrónica', 98.93, 7, 'Proveedor1', '2023-07-05', 'Almacén C')
# (110, 'Objeto110', 'Moda', 473.15, 71, 'Proveedor3', '2023-10-11', 'Almacén C')
# (111, 'Producto111', 'Electrónica', 472.86, 88, 'Proveedor2', '2023-09-12', 'Almacén C')
# (112, 'Artículo112', 'Jardín', 17.03, 20, 'Proveedor2', '2023-05-02', 'Almacén B')
# (113, 'Artículo113', 'Deportes', 376.35, 93, 'Proveedor3', '2023-06-02', 'Almacén C')
# (114, 'Artículo114', 'Jardín', 264.47, 64, 'Proveedor3', '2023-02-20', 'Almacén B')
# (115, 'Artículo115', 'Hogar', 284.25, 18, 'Proveedor3', '2023-11-23', 'Almacén B')
# (116, 'Objeto116', 'Electrónica', 165.62, 30, 'Proveedor3', '2023-04-22', 'Almacén C')
# (117, 'Artículo117', 'Electrónica', 413.14, 77, 'Proveedor3', '2023-07-03', 'Almacén C')
# (118, 'Artículo118', 'Deportes', 268.3, 60, 'Proveedor2', '2023-08-15', 'Almacén B')
# (119, 'Producto119', 'Deportes', 328.77, 56, 'Proveedor3', '2023-01-05', 'Almacén A')
# (120, 'Producto120', 'Moda', 56.73, 10, 'Proveedor3', '2023-04-03', 'Almacén A')
# (121, 'Producto121', 'Jardín', 402.14, 91, 'Proveedor2', '2023-01-28', 'Almacén C')
# (122, 'Artículo122', 'Electrónica', 156.12, 24, 'Proveedor2', '2023-01-25', 'Almacén C')
# (123, 'Objeto123', 'Electrónica', 16.95, 68, 'Proveedor2', '2023-10-18', 'Almacén C')
# (124, 'Artículo124', 'Deportes', 210.9, 67, 'Proveedor3', '2023-10-04', 'Almacén A')
# (125, 'Producto125', 'Deportes', 208.15, 60, 'Proveedor2', '2023-12-07', 'Almacén B')
# (126, 'Producto126', 'Electrónica', 452.99, 69, 'Proveedor1', '2023-08-08', 'Almacén B')
# (127, 'Objeto127', 'Electrónica', 184.4, 97, 'Proveedor1', '2023-12-07', 'Almacén C')
# (128, 'Artículo128', 'Deportes', 29.94, 36, 'Proveedor2', '2023-05-10', 'Almacén B')
# (129, 'Artículo129', 'Electrónica', 223.35, 83, 'Proveedor3', '2023-10-11', 'Almacén A')
# (130, 'Producto130', 'Jardín', 38.36, 30, 'Proveedor1', '2023-03-25', 'Almacén A')
# (131, 'Objeto131', 'Jardín', 23.26, 20, 'Proveedor3', '2023-07-01', 'Almacén B')
# (132, 'Artículo132', 'Moda', 435.15, 44, 'Proveedor3', '2023-01-10', 'Almacén A')
# (133, 'Artículo133', 'Hogar', 195.04, 15, 'Proveedor2', '2023-11-23', 'Almacén A')
# (134, 'Objeto134', 'Jardín', 477.47, 55, 'Proveedor2', '2023-06-27', 'Almacén B')
# (135, 'Artículo135', 'Deportes', 380.91, 27, 'Proveedor2', '2023-03-17', 'Almacén A')
# (136, 'Producto136', 'Electrónica', 422.67, 65, 'Proveedor2', '2023-07-25', 'Almacén C')
# (137, 'Producto137', 'Deportes', 439.61, 29, 'Proveedor2', '2023-10-09', 'Almacén A')
# (138, 'Artículo138', 'Jardín', 152.71, 93, 'Proveedor3', '2023-01-06', 'Almacén A')
# (139, 'Producto139', 'Deportes', 45.88, 2, 'Proveedor2', '2023-05-25', 'Almacén C')
# (140, 'Objeto140', 'Jardín', 300.07, 5, 'Proveedor3', '2023-04-15', 'Almacén A')
# (141, 'Objeto141', 'Deportes', 130.02, 49, 'Proveedor1', '2023-11-24', 'Almacén A')
# (142, 'Artículo142', 'Moda', 105.37, 62, 'Proveedor3', '2023-07-22', 'Almacén A')
# (143, 'Artículo143', 'Jardín', 446.51, 96, 'Proveedor1', '2023-12-21', 'Almacén B')
# (144, 'Producto144', 'Electrónica', 397.06, 56, 'Proveedor1', '2023-01-02', 'Almacén C')
# (145, 'Artículo145', 'Hogar', 355.87, 51, 'Proveedor3', '2023-03-17', 'Almacén C')
# (146, 'Artículo146', 'Hogar', 111.32, 96, 'Proveedor2', '2023-03-06', 'Almacén C')
# (147, 'Objeto147', 'Moda', 329.67, 87, 'Proveedor1', '2023-09-08', 'Almacén A')
# (148, 'Producto148', 'Electrónica', 101.9, 30, 'Proveedor1', '2023-11-17', 'Almacén A')
# (149, 'Artículo149', 'Deportes', 465.64, 3, 'Proveedor3', '2023-05-12', 'Almacén C')
# (150, 'Producto150', 'Electrónica', 256.38, 94, 'Proveedor3', '2023-06-08', 'Almacén A')
# (151, 'Artículo151', 'Moda', 87.74, 58, 'Proveedor1', '2023-07-05', 'Almacén A')
# (152, 'Objeto152', 'Moda', 177.76, 3, 'Proveedor2', '2023-05-17', 'Almacén B')
# (153, 'Artículo153', 'Jardín', 284.61, 53, 'Proveedor3', '2023-12-26', 'Almacén A')
# (154, 'Producto154', 'Moda', 387.24, 48, 'Proveedor2', '2023-12-17', 'Almacén A')
# (155, 'Artículo155', 'Deportes', 184.71, 34, 'Proveedor1', '2023-07-14', 'Almacén B')
# (156, 'Producto156', 'Hogar', 420.99, 28, 'Proveedor1', '2023-11-02', 'Almacén B')
# (157, 'Objeto157', 'Moda', 360.26, 18, 'Proveedor3', '2023-10-03', 'Almacén A')
# (158, 'Artículo158', 'Deportes', 98.09, 6, 'Proveedor1', '2023-11-19', 'Almacén C')
# (159, 'Artículo159', 'Jardín', 446.05, 67, 'Proveedor3', '2023-10-28', 'Almacén B')
# (160, 'Producto160', 'Hogar', 142.9, 27, 'Proveedor2', '2023-03-26', 'Almacén A')
# (161, 'Objeto161', 'Jardín', 176.39, 33, 'Proveedor3', '2023-11-26', 'Almacén C')
# (162, 'Artículo162', 'Hogar', 398.1, 48, 'Proveedor2', '2023-12-21', 'Almacén B')
# (163, 'Artículo163', 'Electrónica', 236.58, 99, 'Proveedor2', '2023-03-05', 'Almacén C')
# (164, 'Producto164', 'Electrónica', 498.18, 78, 'Proveedor1', '2023-11-06', 'Almacén B')
# (165, 'Objeto165', 'Jardín', 69.27, 98, 'Proveedor1', '2023-08-25', 'Almacén B')
# (166, 'Artículo166', 'Moda', 462.07, 8, 'Proveedor1', '2023-10-18', 'Almacén A')
# (167, 'Objeto167', 'Hogar', 334.9, 48, 'Proveedor2', '2023-02-09', 'Almacén C')
# (168, 'Artículo168', 'Moda', 10.21, 82, 'Proveedor3', '2023-01-28', 'Almacén B')
# (169, 'Objeto169', 'Deportes', 424.86, 23, 'Proveedor3', '2023-10-12', 'Almacén C')
# (170, 'Producto170', 'Electrónica', 296.11, 41, 'Proveedor2', '2023-04-20', 'Almacén C')
# (171, 'Producto171', 'Jardín', 223.75, 81, 'Proveedor1', '2023-10-01', 'Almacén A')
# (172, 'Artículo172', 'Electrónica', 159.07, 16, 'Proveedor1', '2023-01-22', 'Almacén A')
# (173, 'Objeto173', 'Electrónica', 387.23, 39, 'Proveedor1', '2023-07-03', 'Almacén C')
# (174, 'Producto174', 'Electrónica', 228.01, 83, 'Proveedor3', '2023-12-05', 'Almacén C')
# (175, 'Objeto175', 'Hogar', 80.91, 90, 'Proveedor1', '2023-02-18', 'Almacén A')
# (176, 'Artículo176', 'Moda', 242.46, 87, 'Proveedor2', '2023-08-03', 'Almacén B')
# (177, 'Objeto177', 'Deportes', 156.52, 69, 'Proveedor2', '2023-05-26', 'Almacén B')
# (178, 'Artículo178', 'Jardín', 279.21, 38, 'Proveedor2', '2023-03-23', 'Almacén C')
# (179, 'Objeto179', 'Electrónica', 370.85, 97, 'Proveedor2', '2023-04-25', 'Almacén C')
# (180, 'Objeto180', 'Deportes', 325.79, 11, 'Proveedor2', '2023-09-05', 'Almacén B')
# (181, 'Objeto181', 'Hogar', 271.69, 58, 'Proveedor2', '2023-02-09', 'Almacén A')
# (182, 'Objeto182', 'Deportes', 174.48, 9, 'Proveedor3', '2023-01-22', 'Almacén A')
# (183, 'Producto183', 'Electrónica', 406.36, 86, 'Proveedor1', '2023-10-10', 'Almacén A')
# (184, 'Objeto184', 'Jardín', 381.54, 76, 'Proveedor3', '2023-07-04', 'Almacén B')
# (185, 'Artículo185', 'Deportes', 206.36, 85, 'Proveedor2', '2023-08-02', 'Almacén B')
# (186, 'Artículo186', 'Deportes', 312.78, 14, 'Proveedor1', '2023-03-07', 'Almacén A')
# (187, 'Producto187', 'Jardín', 38.11, 40, 'Proveedor2', '2023-05-23', 'Almacén C')
# (188, 'Producto188', 'Hogar', 123.16, 22, 'Proveedor3', '2023-06-13', 'Almacén B')
# (189, 'Artículo189', 'Electrónica', 471.17, 83, 'Proveedor3', '2023-01-25', 'Almacén A')
# (190, 'Producto190', 'Deportes', 263.32, 30, 'Proveedor2', '2023-02-03', 'Almacén B')
# (191, 'Artículo191', 'Jardín', 336.95, 99, 'Proveedor1', '2023-07-03', 'Almacén B')
# (192, 'Producto192', 'Hogar', 470.5, 22, 'Proveedor1', '2023-03-22', 'Almacén C')
# (193, 'Artículo193', 'Hogar', 231.71, 68, 'Proveedor1', '2023-05-23', 'Almacén A')
# (194, 'Producto194', 'Jardín', 52.15, 5, 'Proveedor1', '2023-04-20', 'Almacén B')
# (195, 'Producto195', 'Jardín', 474.1, 56, 'Proveedor1', '2023-09-18', 'Almacén A')
# (196, 'Objeto196', 'Moda', 478.22, 65, 'Proveedor2', '2023-08-05', 'Almacén C')
# (197, 'Artículo197', 'Electrónica', 119.41, 21, 'Proveedor1', '2023-06-17', 'Almacén B')
# (198, 'Objeto198', 'Electrónica', 272.96, 11, 'Proveedor1', '2023-05-08', 'Almacén C')
# (199, 'Artículo199', 'Moda', 249.25, 34, 'Proveedor2', '2023-05-22', 'Almacén A')
# (200, 'Objeto200', 'Hogar', 341.98, 41, 'Proveedor3', '2023-09-09', 'Almacén C')
# (201, 'Producto201', 'Jardín', 265.64, 85, 'Proveedor3', '2023-09-24', 'Almacén C')
# (202, 'Objeto202', 'Jardín', 143.68, 93, 'Proveedor2', '2023-12-03', 'Almacén B')
# (203, 'Producto203', 'Electrónica', 172.44, 35, 'Proveedor1', '2023-11-17', 'Almacén A')
# (204, 'Artículo204', 'Moda', 26.21, 97, 'Proveedor3', '2023-03-13', 'Almacén C')
# (205, 'Artículo205', 'Hogar', 178.44, 95, 'Proveedor2', '2023-01-08', 'Almacén A')
# (206, 'Producto206', 'Jardín', 414.65, 60, 'Proveedor1', '2023-08-03', 'Almacén B')
# (207, 'Producto207', 'Moda', 404.51, 18, 'Proveedor2', '2023-07-14', 'Almacén A')
# (208, 'Producto208', 'Hogar', 242.7, 19, 'Proveedor3', '2023-01-06', 'Almacén A')
# (209, 'Artículo209', 'Jardín', 433.37, 53, 'Proveedor3', '2023-11-11', 'Almacén A')
# (210, 'Objeto210', 'Deportes', 135.94, 36, 'Proveedor1', '2023-10-04', 'Almacén A')
# (211, 'Objeto211', 'Deportes', 141.79, 71, 'Proveedor1', '2023-01-24', 'Almacén B')
# (212, 'Objeto212', 'Electrónica', 396.92, 43, 'Proveedor3', '2023-01-01', 'Almacén A')
# (213, 'Producto213', 'Hogar', 174.05, 90, 'Proveedor1', '2023-11-28', 'Almacén A')
# (214, 'Objeto214', 'Electrónica', 62.88, 23, 'Proveedor1', '2023-12-14', 'Almacén A')
# (215, 'Artículo215', 'Hogar', 337.62, 2, 'Proveedor2', '2023-02-25', 'Almacén B')
# (216, 'Producto216', 'Hogar', 287.97, 20, 'Proveedor1', '2023-10-21', 'Almacén A')
# (217, 'Artículo217', 'Jardín', 322.35, 41, 'Proveedor1', '2023-03-11', 'Almacén C')
# (218, 'Producto218', 'Moda', 332.05, 53, 'Proveedor1', '2023-04-09', 'Almacén C')
# (219, 'Producto219', 'Electrónica', 289.15, 56, 'Proveedor2', '2023-05-11', 'Almacén C')
# (220, 'Objeto220', 'Deportes', 41.79, 76, 'Proveedor2', '2023-09-02', 'Almacén B')
# (221, 'Producto221', 'Moda', 430.75, 77, 'Proveedor1', '2023-05-19', 'Almacén C')
# (222, 'Artículo222', 'Electrónica', 390.58, 86, 'Proveedor1', '2023-12-18', 'Almacén A')
# (223, 'Objeto223', 'Moda', 300.46, 50, 'Proveedor2', '2023-06-04', 'Almacén B')
# (224, 'Objeto224', 'Jardín', 324.03, 69, 'Proveedor1', '2023-12-16', 'Almacén A')
# (225, 'Objeto225', 'Deportes', 34.77, 48, 'Proveedor1', '2023-07-02', 'Almacén A')
# (226, 'Objeto226', 'Jardín', 389.27, 63, 'Proveedor1', '2023-09-16', 'Almacén B')
# (227, 'Artículo227', 'Jardín', 243.98, 30, 'Proveedor3', '2023-03-18', 'Almacén A')
# (228, 'Artículo228', 'Hogar', 113.13, 72, 'Proveedor3', '2023-09-20', 'Almacén A')
# (229, 'Objeto229', 'Deportes', 334.85, 11, 'Proveedor2', '2023-06-23', 'Almacén B')
# (230, 'Producto230', 'Hogar', 174.91, 17, 'Proveedor3', '2023-08-26', 'Almacén B')
# (231, 'Objeto231', 'Electrónica', 233.4, 84, 'Proveedor3', '2023-05-22', 'Almacén C')
# (232, 'Objeto232', 'Jardín', 245.34, 99, 'Proveedor2', '2023-08-15', 'Almacén B')
# (233, 'Producto233', 'Deportes', 397.92, 4, 'Proveedor3', '2023-06-20', 'Almacén C')
# (234, 'Artículo234', 'Moda', 314.04, 66, 'Proveedor2', '2023-10-22', 'Almacén C')
# (235, 'Artículo235', 'Moda', 35.35, 25, 'Proveedor1', '2023-09-21', 'Almacén C')
# (236, 'Objeto236', 'Deportes', 324.5, 25, 'Proveedor3', '2023-06-24', 'Almacén A')
# (237, 'Artículo237', 'Deportes', 189.92, 74, 'Proveedor1', '2023-10-15', 'Almacén C')
# (238, 'Producto238', 'Electrónica', 486.3, 72, 'Proveedor2', '2023-01-18', 'Almacén C')
# (239, 'Objeto239', 'Jardín', 299.81, 44, 'Proveedor3', '2023-01-20', 'Almacén C')
# (240, 'Artículo240', 'Deportes', 307.73, 2, 'Proveedor3', '2023-02-03', 'Almacén B')
# (241, 'Objeto241', 'Deportes', 440.64, 47, 'Proveedor1', '2023-01-09', 'Almacén B')
# (242, 'Artículo242', 'Electrónica', 277.99, 75, 'Proveedor3', '2023-11-12', 'Almacén A')
# (243, 'Objeto243', 'Hogar', 362.38, 36, 'Proveedor1', '2023-06-26', 'Almacén A')
# (244, 'Objeto244', 'Jardín', 207.61, 11, 'Proveedor2', '2023-07-08', 'Almacén A')
# (245, 'Artículo245', 'Moda', 151.87, 50, 'Proveedor2', '2023-03-13', 'Almacén C')
# (246, 'Artículo246', 'Electrónica', 486.4, 49, 'Proveedor3', '2023-02-13', 'Almacén C')
# (247, 'Producto247', 'Deportes', 47.12, 66, 'Proveedor2', '2023-02-18', 'Almacén A')
# (248, 'Artículo248', 'Hogar', 54.56, 100, 'Proveedor1', '2023-04-28', 'Almacén B')
# (249, 'Producto249', 'Jardín', 265.41, 85, 'Proveedor2', '2023-09-09', 'Almacén C')
# (250, 'Objeto250', 'Moda', 386.82, 2, 'Proveedor2', '2023-02-07', 'Almacén A')
# (251, 'Artículo251', 'Electrónica', 225.99, 100, 'Proveedor1', '2023-10-18', 'Almacén A')
# (252, 'Producto252', 'Moda', 10.26, 77, 'Proveedor3', '2023-12-11', 'Almacén A')
# (253, 'Objeto253', 'Electrónica', 318.3, 29, 'Proveedor1', '2023-02-11', 'Almacén A')
# (254, 'Producto254', 'Deportes', 379.31, 81, 'Proveedor1', '2023-06-22', 'Almacén A')
# (255, 'Objeto255', 'Jardín', 160.23, 23, 'Proveedor3', '2023-05-23', 'Almacén A')
# (256, 'Objeto256', 'Moda', 166, 40, 'Proveedor3', '2023-08-07', 'Almacén B')
# (257, 'Producto257', 'Jardín', 452.33, 19, 'Proveedor1', '2023-10-06', 'Almacén C')
# (258, 'Objeto258', 'Moda', 404.26, 42, 'Proveedor1', '2023-07-04', 'Almacén B')
# (259, 'Artículo259', 'Electrónica', 342.22, 6, 'Proveedor3', '2023-11-27', 'Almacén B')
# (260, 'Producto260', 'Electrónica', 456.13, 99, 'Proveedor2', '2023-07-01', 'Almacén C')
# (261, 'Producto261', 'Jardín', 181.12, 51, 'Proveedor1', '2023-06-25', 'Almacén A')
# (262, 'Artículo262', 'Hogar', 134.84, 31, 'Proveedor1', '2023-03-01', 'Almacén C')
# (263, 'Producto263', 'Deportes', 265.74, 4, 'Proveedor2', '2023-07-25', 'Almacén B')
# (264, 'Producto264', 'Jardín', 237.85, 76, 'Proveedor3', '2023-08-17', 'Almacén C')
# (265, 'Producto265', 'Hogar', 463.09, 81, 'Proveedor2', '2023-12-20', 'Almacén B')
# (266, 'Objeto266', 'Electrónica', 66.3, 87, 'Proveedor1', '2023-05-11', 'Almacén B')
# (267, 'Producto267', 'Deportes', 447.84, 90, 'Proveedor2', '2023-07-21', 'Almacén B')
# (268, 'Artículo268', 'Electrónica', 420.54, 38, 'Proveedor3', '2023-08-04', 'Almacén C')
# (269, 'Objeto269', 'Moda', 413.73, 90, 'Proveedor2', '2023-07-26', 'Almacén C')
# (270, 'Objeto270', 'Deportes', 104.82, 26, 'Proveedor1', '2023-11-21', 'Almacén B')
# (271, 'Artículo271', 'Hogar', 201.92, 30, 'Proveedor2', '2023-01-08', 'Almacén C')
# (272, 'Objeto272', 'Electrónica', 273.97, 33, 'Proveedor2', '2023-04-06', 'Almacén B')
# (273, 'Objeto273', 'Deportes', 222.73, 7, 'Proveedor2', '2023-03-16', 'Almacén B')
# (274, 'Objeto274', 'Deportes', 300.43, 47, 'Proveedor2', '2023-01-11', 'Almacén A')
# (275, 'Artículo275', 'Jardín', 134.76, 18, 'Proveedor3', '2023-04-05', 'Almacén C')
# (276, 'Objeto276', 'Moda', 286.46, 98, 'Proveedor3', '2023-04-04', 'Almacén C')
# (277, 'Producto277', 'Deportes', 365.54, 31, 'Proveedor3', '2023-11-02', 'Almacén A')
# (278, 'Producto278', 'Hogar', 305.36, 51, 'Proveedor3', '2023-10-11', 'Almacén B')
# (279, 'Objeto279', 'Moda', 316.18, 60, 'Proveedor3', '2023-03-21', 'Almacén A')
# (280, 'Objeto280', 'Jardín', 275.66, 36, 'Proveedor3', '2023-02-17', 'Almacén A')
# (281, 'Producto281', 'Moda', 416.96, 71, 'Proveedor2', '2023-04-22', 'Almacén A')
# (282, 'Artículo282', 'Jardín', 277.89, 99, 'Proveedor3', '2023-04-20', 'Almacén A')
# (283, 'Artículo283', 'Jardín', 303.95, 39, 'Proveedor2', '2023-08-22', 'Almacén B')
# (284, 'Objeto284', 'Deportes', 249.49, 90, 'Proveedor1', '2023-05-02', 'Almacén A')
# (285, 'Objeto285', 'Hogar', 335.03, 92, 'Proveedor1', '2023-01-20', 'Almacén B')
# (286, 'Producto286', 'Moda', 395.56, 44, 'Proveedor3', '2023-10-04', 'Almacén B')
# (287, 'Objeto287', 'Moda', 229.93, 38, 'Proveedor3', '2023-06-26', 'Almacén B')
# (288, 'Producto288', 'Moda', 483.3, 33, 'Proveedor3', '2023-02-06', 'Almacén B')
# (289, 'Artículo289', 'Hogar', 34.63, 6, 'Proveedor1', '2023-10-16', 'Almacén A')
# (290, 'Objeto290', 'Hogar', 145.35, 13, 'Proveedor2', '2023-05-10', 'Almacén B')
# (291, 'Objeto291', 'Moda', 410.93, 43, 'Proveedor2', '2023-06-27', 'Almacén A')
# (292, 'Producto292', 'Electrónica', 495.78, 32, 'Proveedor1', '2023-08-14', 'Almacén C')
# (293, 'Producto293', 'Jardín', 350.24, 98, 'Proveedor2', '2023-02-08', 'Almacén C')
# (294, 'Artículo294', 'Jardín', 46.3, 25, 'Proveedor3', '2023-03-06', 'Almacén C')
# (295, 'Producto295', 'Jardín', 296.97, 44, 'Proveedor2', '2023-03-07', 'Almacén C')
# (296, 'Producto296', 'Hogar', 243.36, 78, 'Proveedor3', '2023-12-23', 'Almacén C')
# (297, 'Artículo297', 'Jardín', 68.53, 80, 'Proveedor2', '2023-08-14', 'Almacén A')
# (298, 'Objeto298', 'Hogar', 28.8, 40, 'Proveedor1', '2023-06-02', 'Almacén B')
# (299, 'Producto299', 'Electrónica', 71.1, 11, 'Proveedor2', '2023-08-07', 'Almacén B')
# (300, 'Producto300', 'Moda', 468.73, 97, 'Proveedor2', '2023-04-21', 'Almacén C')
# (301, 'Objeto301', 'Deportes', 293.79, 45, 'Proveedor3', '2023-12-27', 'Almacén A')
# (302, 'Objeto302', 'Jardín', 436.54, 92, 'Proveedor3', '2023-10-02', 'Almacén A')
# (303, 'Objeto303', 'Hogar', 176.21, 42, 'Proveedor1', '2023-05-25', 'Almacén A')
# (304, 'Objeto304', 'Electrónica', 295.19, 27, 'Proveedor1', '2023-08-20', 'Almacén C')
# (305, 'Objeto305', 'Jardín', 405.51, 42, 'Proveedor1', '2023-06-09', 'Almacén A')
# (306, 'Producto306', 'Electrónica', 342.73, 44, 'Proveedor2', '2023-09-19', 'Almacén A')
# (307, 'Artículo307', 'Jardín', 296.43, 2, 'Proveedor3', '2023-12-18', 'Almacén C')
# (308, 'Artículo308', 'Deportes', 13.86, 67, 'Proveedor1', '2023-03-22', 'Almacén B')
# (309, 'Producto309', 'Moda', 437.6, 26, 'Proveedor2', '2023-06-28', 'Almacén C')
# (310, 'Objeto310', 'Hogar', 375.69, 22, 'Proveedor3', '2023-12-26', 'Almacén A')
# (311, 'Objeto311', 'Electrónica', 204.76, 56, 'Proveedor2', '2023-12-05', 'Almacén B')
# (312, 'Objeto312', 'Moda', 453.23, 96, 'Proveedor1', '2023-11-01', 'Almacén A')
# (313, 'Artículo313', 'Electrónica', 446.84, 60, 'Proveedor3', '2023-03-13', 'Almacén A')
# (314, 'Artículo314', 'Hogar', 227.55, 1, 'Proveedor3', '2023-04-14', 'Almacén A')
# (315, 'Producto315', 'Jardín', 461.08, 54, 'Proveedor1', '2023-03-24', 'Almacén A')
# (316, 'Artículo316', 'Jardín', 386, 70, 'Proveedor3', '2023-09-20', 'Almacén A')
# (317, 'Producto317', 'Electrónica', 59.47, 56, 'Proveedor3', '2023-09-13', 'Almacén A')
# (318, 'Producto318', 'Hogar', 97.35, 14, 'Proveedor3', '2023-06-18', 'Almacén B')
# (319, 'Artículo319', 'Deportes', 365.6, 53, 'Proveedor1', '2023-09-05', 'Almacén C')
# (320, 'Artículo320', 'Moda', 451.37, 30, 'Proveedor2', '2023-05-09', 'Almacén B')
# (321, 'Producto321', 'Deportes', 422.19, 6, 'Proveedor3', '2023-11-09', 'Almacén C')
# (322, 'Artículo322', 'Electrónica', 222.6, 51, 'Proveedor1', '2023-07-23', 'Almacén C')
# (323, 'Producto323', 'Electrónica', 414.03, 99, 'Proveedor1', '2023-07-16', 'Almacén C')
# (324, 'Objeto324', 'Jardín', 189.3, 30, 'Proveedor1', '2023-05-02', 'Almacén A')
# (325, 'Artículo325', 'Jardín', 455.66, 91, 'Proveedor3', '2023-06-22', 'Almacén A')
# (326, 'Producto326', 'Jardín', 180.4, 28, 'Proveedor1', '2023-09-13', 'Almacén A')
# (327, 'Artículo327', 'Moda', 238.22, 9, 'Proveedor3', '2023-07-27', 'Almacén C')
# (328, 'Producto328', 'Electrónica', 47.72, 64, 'Proveedor3', '2023-01-25', 'Almacén A')
# (329, 'Producto329', 'Hogar', 300.09, 20, 'Proveedor1', '2023-04-19', 'Almacén A')
# (330, 'Objeto330', 'Moda', 301.15, 55, 'Proveedor1', '2023-08-24', 'Almacén A')
# (331, 'Objeto331', 'Moda', 361.56, 84, 'Proveedor1', '2023-12-13', 'Almacén C')
# (332, 'Artículo332', 'Deportes', 351.47, 16, 'Proveedor3', '2023-02-07', 'Almacén B')
# (333, 'Objeto333', 'Hogar', 448.81, 82, 'Proveedor1', '2023-11-25', 'Almacén B')
# (334, 'Artículo334', 'Moda', 137.05, 32, 'Proveedor1', '2023-11-03', 'Almacén B')
# (335, 'Objeto335', 'Moda', 92.13, 87, 'Proveedor1', '2023-04-17', 'Almacén B')
# (336, 'Objeto336', 'Electrónica', 169.58, 5, 'Proveedor2', '2023-01-08', 'Almacén B')
# (337, 'Producto337', 'Electrónica', 223.44, 41, 'Proveedor3', '2023-05-20', 'Almacén A')
# (338, 'Artículo338', 'Moda', 183.56, 2, 'Proveedor1', '2023-06-28', 'Almacén A')
# (339, 'Producto339', 'Deportes', 198.27, 63, 'Proveedor1', '2023-11-28', 'Almacén A')
# (340, 'Objeto340', 'Electrónica', 160.36, 47, 'Proveedor2', '2023-08-07', 'Almacén C')
# (341, 'Artículo341', 'Jardín', 280.78, 81, 'Proveedor2', '2023-04-01', 'Almacén C')
# (342, 'Artículo342', 'Hogar', 132.92, 73, 'Proveedor2', '2023-11-01', 'Almacén C')
# (343, 'Producto343', 'Electrónica', 313.48, 32, 'Proveedor3', '2023-11-21', 'Almacén C')
# (344, 'Artículo344', 'Hogar', 298.55, 42, 'Proveedor2', '2023-08-25', 'Almacén C')
# (345, 'Producto345', 'Hogar', 173.44, 78, 'Proveedor1', '2023-04-24', 'Almacén A')
# (346, 'Objeto346', 'Deportes', 102.49, 14, 'Proveedor1', '2023-10-14', 'Almacén B')
# (347, 'Producto347', 'Jardín', 126.87, 54, 'Proveedor3', '2023-04-07', 'Almacén A')
# (348, 'Producto348', 'Moda', 233.97, 93, 'Proveedor1', '2023-11-05', 'Almacén B')
# (349, 'Objeto349', 'Deportes', 299.29, 5, 'Proveedor1', '2023-01-22', 'Almacén A')
# (350, 'Objeto350', 'Hogar', 343.97, 18, 'Proveedor1', '2023-09-17', 'Almacén A')
# (351, 'Objeto351', 'Moda', 166.02, 76, 'Proveedor1', '2023-05-26', 'Almacén C')
# (352, 'Objeto352', 'Hogar', 85.1, 44, 'Proveedor1', '2023-07-17', 'Almacén B')
# (353, 'Producto353', 'Deportes', 119.3, 62, 'Proveedor2', '2023-06-27', 'Almacén A')
# (354, 'Producto354', 'Jardín', 85.83, 80, 'Proveedor3', '2023-07-15', 'Almacén A')
# (355, 'Objeto355', 'Moda', 260.61, 4, 'Proveedor3', '2023-12-23', 'Almacén A')
# (356, 'Objeto356', 'Deportes', 359.22, 23, 'Proveedor2', '2023-06-19', 'Almacén C')
# (357, 'Objeto357', 'Jardín', 355.17, 10, 'Proveedor1', '2023-08-26', 'Almacén C')
# (358, 'Producto358', 'Electrónica', 42.32, 12, 'Proveedor3', '2023-06-28', 'Almacén B')
# (359, 'Producto359', 'Moda', 61.77, 37, 'Proveedor1', '2023-06-20', 'Almacén A')
# (360, 'Producto360', 'Jardín', 28.67, 49, 'Proveedor3', '2023-12-25', 'Almacén B')
# (361, 'Producto361', 'Hogar', 388.7, 13, 'Proveedor2', '2023-04-19', 'Almacén C')
# (362, 'Objeto362', 'Deportes', 140.45, 31, 'Proveedor1', '2023-09-13', 'Almacén B')
# (363, 'Artículo363', 'Deportes', 139.86, 78, 'Proveedor3', '2023-09-15', 'Almacén C')
# (364, 'Producto364', 'Electrónica', 190.09, 36, 'Proveedor2', '2023-10-05', 'Almacén C')
# (365, 'Objeto365', 'Moda', 162.51, 83, 'Proveedor1', '2023-06-16', 'Almacén A')
# (366, 'Objeto366', 'Electrónica', 257.04, 59, 'Proveedor1', '2023-02-04', 'Almacén A')
# (367, 'Objeto367', 'Moda', 241.37, 37, 'Proveedor2', '2023-10-01', 'Almacén B')
# (368, 'Artículo368', 'Jardín', 224.6, 32, 'Proveedor3', '2023-01-07', 'Almacén A')
# (369, 'Artículo369', 'Hogar', 376.87, 92, 'Proveedor1', '2023-11-01', 'Almacén B')
# (370, 'Objeto370', 'Hogar', 446.05, 46, 'Proveedor2', '2023-03-09', 'Almacén C')
# (371, 'Objeto371', 'Deportes', 367.48, 5, 'Proveedor3', '2023-07-09', 'Almacén B')
# (372, 'Objeto372', 'Hogar', 249.36, 49, 'Proveedor2', '2023-08-12', 'Almacén C')
# (373, 'Producto373', 'Deportes', 340.38, 44, 'Proveedor1', '2023-07-06', 'Almacén A')
# (374, 'Producto374', 'Jardín', 25.26, 32, 'Proveedor2', '2023-11-28', 'Almacén A')
# (375, 'Artículo375', 'Hogar', 74.37, 10, 'Proveedor3', '2023-08-03', 'Almacén B')
# (376, 'Objeto376', 'Electrónica', 148.05, 43, 'Proveedor3', '2023-01-16', 'Almacén A')
# (377, 'Objeto377', 'Moda', 334.64, 72, 'Proveedor2', '2023-06-26', 'Almacén C')
# (378, 'Objeto378', 'Electrónica', 265.5, 5, 'Proveedor3', '2023-01-23', 'Almacén C')
# (379, 'Artículo379', 'Moda', 449.97, 92, 'Proveedor2', '2023-02-14', 'Almacén B')
# (380, 'Producto380', 'Moda', 43.7, 81, 'Proveedor3', '2023-04-08', 'Almacén A')
# (381, 'Artículo381', 'Electrónica', 317.31, 89, 'Proveedor2', '2023-05-20', 'Almacén B')
# (382, 'Artículo382', 'Electrónica', 59.13, 47, 'Proveedor1', '2023-10-13', 'Almacén A')
# (383, 'Objeto383', 'Moda', 391.88, 74, 'Proveedor1', '2023-11-19', 'Almacén B')
# (384, 'Objeto384', 'Deportes', 288.12, 52, 'Proveedor3', '2023-12-07', 'Almacén B')
# (385, 'Objeto385', 'Hogar', 49.05, 62, 'Proveedor3', '2023-08-16', 'Almacén A')
# (386, 'Artículo386', 'Hogar', 292.94, 62, 'Proveedor2', '2023-04-01', 'Almacén C')
# (387, 'Producto387', 'Jardín', 237.05, 82, 'Proveedor2', '2023-06-12', 'Almacén A')
# (388, 'Objeto388', 'Moda', 450.99, 66, 'Proveedor3', '2023-12-01', 'Almacén C')
# (389, 'Artículo389', 'Deportes', 395.21, 38, 'Proveedor3', '2023-05-04', 'Almacén C')
# (390, 'Objeto390', 'Electrónica', 461.21, 67, 'Proveedor2', '2023-09-23', 'Almacén B')
# (391, 'Objeto391', 'Moda', 87.17, 45, 'Proveedor2', '2023-11-19', 'Almacén C')
# (392, 'Producto392', 'Deportes', 84.27, 74, 'Proveedor3', '2023-08-20', 'Almacén A')
# (393, 'Objeto393', 'Electrónica', 16.35, 46, 'Proveedor2', '2023-12-09', 'Almacén A')
# (394, 'Artículo394', 'Electrónica', 358.56, 6, 'Proveedor3', '2023-04-15', 'Almacén A')
# (395, 'Artículo395', 'Deportes', 395.77, 61, 'Proveedor3', '2023-05-28', 'Almacén B')
# (396, 'Artículo396', 'Hogar', 171.28, 39, 'Proveedor3', '2023-02-21', 'Almacén B')
# (397, 'Objeto397', 'Jardín', 200.02, 41, 'Proveedor3', '2023-05-09', 'Almacén A')
# (398, 'Objeto398', 'Moda', 200.15, 16, 'Proveedor3', '2023-05-18', 'Almacén B')
# (399, 'Artículo399', 'Jardín', 120.53, 71, 'Proveedor1', '2023-04-06', 'Almacén B')
# (400, 'Producto400', 'Jardín', 392.3, 70, 'Proveedor1', '2023-02-11', 'Almacén C')
# (401, 'Objeto401', 'Moda', 444.81, 89, 'Proveedor1', '2023-05-09', 'Almacén B')
# (402, 'Producto402', 'Jardín', 185.84, 19, 'Proveedor2', '2023-10-20', 'Almacén A')
# (403, 'Objeto403', 'Electrónica', 292.57, 68, 'Proveedor2', '2023-05-25', 'Almacén C')
# (404, 'Artículo404', 'Electrónica', 149.55, 99, 'Proveedor1', '2023-05-05', 'Almacén B')
# (405, 'Producto405', 'Electrónica', 427.73, 44, 'Proveedor1', '2023-05-18', 'Almacén B')
# (406, 'Artículo406', 'Electrónica', 29.28, 23, 'Proveedor3', '2023-12-27', 'Almacén B')
# (407, 'Producto407', 'Hogar', 44.42, 47, 'Proveedor1', '2023-01-26', 'Almacén C')
# (408, 'Artículo408', 'Hogar', 469.79, 33, 'Proveedor3', '2023-07-18', 'Almacén B')
# (409, 'Objeto409', 'Electrónica', 444.14, 17, 'Proveedor2', '2023-12-07', 'Almacén A')
# (410, 'Producto410', 'Hogar', 176.75, 24, 'Proveedor3', '2023-08-14', 'Almacén A')
# (411, 'Artículo411', 'Hogar', 455.76, 44, 'Proveedor1', '2023-01-21', 'Almacén C')
# (412, 'Objeto412', 'Jardín', 104.07, 55, 'Proveedor3', '2023-08-07', 'Almacén C')
# (413, 'Artículo413', 'Electrónica', 452.46, 72, 'Proveedor3', '2023-04-28', 'Almacén C')
# (414, 'Objeto414', 'Moda', 40.05, 63, 'Proveedor3', '2023-07-14', 'Almacén A')
# (415, 'Artículo415', 'Moda', 68.25, 23, 'Proveedor3', '2023-05-06', 'Almacén A')
# (416, 'Artículo416', 'Moda', 232.17, 18, 'Proveedor3', '2023-06-17', 'Almacén C')
# (417, 'Artículo417', 'Hogar', 133.52, 23, 'Proveedor1', '2023-12-03', 'Almacén A')
# (418, 'Producto418', 'Moda', 491.24, 98, 'Proveedor2', '2023-09-16', 'Almacén A')
# (419, 'Artículo419', 'Electrónica', 319.33, 55, 'Proveedor2', '2023-08-04', 'Almacén A')
# (420, 'Objeto420', 'Electrónica', 61.67, 43, 'Proveedor2', '2023-09-10', 'Almacén A')
# (421, 'Producto421', 'Hogar', 30.36, 42, 'Proveedor3', '2023-01-05', 'Almacén C')
# (422, 'Producto422', 'Deportes', 470.23, 66, 'Proveedor3', '2023-04-23', 'Almacén A')
# (423, 'Artículo423', 'Moda', 215.03, 99, 'Proveedor1', '2023-12-09', 'Almacén B')
# (424, 'Producto424', 'Hogar', 465.13, 26, 'Proveedor2', '2023-03-28', 'Almacén C')
# (425, 'Objeto425', 'Hogar', 101.57, 76, 'Proveedor3', '2023-08-26', 'Almacén A')
# (426, 'Producto426', 'Jardín', 216.87, 63, 'Proveedor3', '2023-07-02', 'Almacén C')
# (427, 'Producto427', 'Hogar', 241.05, 37, 'Proveedor3', '2023-11-26', 'Almacén B')
# (428, 'Producto428', 'Deportes', 394.22, 28, 'Proveedor2', '2023-11-15', 'Almacén C')
# (429, 'Artículo429', 'Moda', 408.38, 7, 'Proveedor3', '2023-04-01', 'Almacén A')
# (430, 'Producto430', 'Hogar', 284.49, 6, 'Proveedor1', '2023-01-07', 'Almacén B')
# (431, 'Producto431', 'Moda', 283.29, 70, 'Proveedor3', '2023-10-28', 'Almacén B')
# (432, 'Artículo432', 'Moda', 458.76, 11, 'Proveedor1', '2023-06-15', 'Almacén C')
# (433, 'Artículo433', 'Electrónica', 487.53, 83, 'Proveedor2', '2023-03-13', 'Almacén B')
# (434, 'Producto434', 'Jardín', 16.74, 92, 'Proveedor2', '2023-07-04', 'Almacén B')
# (435, 'Objeto435', 'Deportes', 366.73, 50, 'Proveedor3', '2023-05-20', 'Almacén C')
# (436, 'Objeto436', 'Hogar', 17.33, 94, 'Proveedor2', '2023-06-14', 'Almacén A')
# (437, 'Producto437', 'Jardín', 242.58, 27, 'Proveedor2', '2023-06-08', 'Almacén B')
# (438, 'Objeto438', 'Deportes', 232.67, 78, 'Proveedor2', '2023-12-15', 'Almacén B')
# (439, 'Artículo439', 'Deportes', 116.29, 82, 'Proveedor3', '2023-06-22', 'Almacén C')
# (440, 'Producto440', 'Moda', 261.89, 39, 'Proveedor2', '2023-04-15', 'Almacén B')
# (441, 'Producto441', 'Electrónica', 280.84, 14, 'Proveedor2', '2023-12-27', 'Almacén C')
# (442, 'Artículo442', 'Moda', 282.85, 45, 'Proveedor3', '2023-03-17', 'Almacén A')
# (443, 'Artículo443', 'Hogar', 436.88, 69, 'Proveedor2', '2023-01-22', 'Almacén B')
# (444, 'Objeto444', 'Moda', 441.3, 6, 'Proveedor2', '2023-11-07', 'Almacén A')
# (445, 'Objeto445', 'Moda', 235.89, 16, 'Proveedor2', '2023-08-11', 'Almacén B')
# (446, 'Artículo446', 'Hogar', 23.6, 64, 'Proveedor1', '2023-10-09', 'Almacén C')
# (447, 'Objeto447', 'Jardín', 385.59, 81, 'Proveedor3', '2023-02-12', 'Almacén A')
# (448, 'Artículo448', 'Deportes', 118.74, 30, 'Proveedor1', '2023-09-19', 'Almacén B')
# (449, 'Objeto449', 'Jardín', 226.22, 24, 'Proveedor2', '2023-02-11', 'Almacén C')
# (450, 'Producto450', 'Electrónica', 276.91, 92, 'Proveedor2', '2023-10-18', 'Almacén A')
# (451, 'Artículo451', 'Jardín', 23.9, 67, 'Proveedor2', '2023-03-16', 'Almacén B')
# (452, 'Artículo452', 'Electrónica', 63.23, 73, 'Proveedor1', '2023-01-11', 'Almacén B')
# (453, 'Artículo453', 'Moda', 269.83, 69, 'Proveedor1', '2023-06-05', 'Almacén C')
# (454, 'Artículo454', 'Electrónica', 270.65, 86, 'Proveedor3', '2023-08-23', 'Almacén C')
# (455, 'Artículo455', 'Hogar', 79.88, 4, 'Proveedor2', '2023-09-02', 'Almacén C')
# (456, 'Artículo456', 'Deportes', 392.45, 78, 'Proveedor3', '2023-06-14', 'Almacén A')
# (457, 'Producto457', 'Hogar', 182.92, 78, 'Proveedor2', '2023-06-04', 'Almacén A')
# (458, 'Artículo458', 'Hogar', 482.4, 5, 'Proveedor3', '2023-10-02', 'Almacén C')
# (459, 'Artículo459', 'Hogar', 148.2, 28, 'Proveedor3', '2023-02-19', 'Almacén B')
# (460, 'Artículo460', 'Hogar', 457.86, 26, 'Proveedor2', '2023-05-26', 'Almacén A')
# (461, 'Objeto461', 'Electrónica', 399.38, 91, 'Proveedor2', '2023-05-25', 'Almacén B')
# (462, 'Producto462', 'Jardín', 272.36, 33, 'Proveedor3', '2023-07-09', 'Almacén C')
# (463, 'Objeto463', 'Deportes', 332.98, 89, 'Proveedor3', '2023-06-05', 'Almacén B')
# (464, 'Producto464', 'Jardín', 95.32, 20, 'Proveedor2', '2023-06-11', 'Almacén A')
# (465, 'Producto465', 'Hogar', 274.23, 87, 'Proveedor3', '2023-03-08', 'Almacén C')
# (466, 'Artículo466', 'Moda', 473.69, 15, 'Proveedor2', '2023-12-25', 'Almacén A')
# (467, 'Objeto467', 'Hogar', 477.23, 97, 'Proveedor1', '2023-05-04', 'Almacén B')
# (468, 'Producto468', 'Hogar', 184.34, 17, 'Proveedor3', '2023-06-12', 'Almacén A')
# (469, 'Producto469', 'Electrónica', 43.41, 89, 'Proveedor1', '2023-07-12', 'Almacén C')
# (470, 'Artículo470', 'Moda', 75.43, 75, 'Proveedor1', '2023-03-03', 'Almacén C')
# (471, 'Objeto471', 'Electrónica', 63.71, 84, 'Proveedor2', '2023-12-15', 'Almacén C')
# (472, 'Artículo472', 'Electrónica', 375.38, 97, 'Proveedor3', '2023-12-21', 'Almacén C')
# (473, 'Artículo473', 'Deportes', 275.22, 67, 'Proveedor3', '2023-02-23', 'Almacén A')
# (474, 'Producto474', 'Electrónica', 179.64, 69, 'Proveedor2', '2023-06-10', 'Almacén B')
# (475, 'Objeto475', 'Moda', 46.59, 26, 'Proveedor3', '2023-07-11', 'Almacén B')
# (476, 'Artículo476', 'Jardín', 254.21, 15, 'Proveedor2', '2023-11-13', 'Almacén B')
# (477, 'Producto477', 'Jardín', 281.82, 5, 'Proveedor3', '2023-05-17', 'Almacén C')
# (478, 'Objeto478', 'Hogar', 440.07, 25, 'Proveedor1', '2023-05-17', 'Almacén A')
# (479, 'Objeto479', 'Electrónica', 417.51, 26, 'Proveedor1', '2023-03-23', 'Almacén A')
# (480, 'Artículo480', 'Moda', 280.49, 95, 'Proveedor3', '2023-11-27', 'Almacén B')
# (481, 'Objeto481', 'Hogar', 483.21, 55, 'Proveedor3', '2023-12-14', 'Almacén C')
# (482, 'Producto482', 'Deportes', 238.07, 27, 'Proveedor1', '2023-03-22', 'Almacén B')
# (483, 'Artículo483', 'Electrónica', 452.22, 73, 'Proveedor3', '2023-01-11', 'Almacén A')
# (484, 'Producto484', 'Jardín', 460.02, 78, 'Proveedor2', '2023-07-27', 'Almacén C')
# (485, 'Objeto485', 'Jardín', 215.11, 46, 'Proveedor3', '2023-02-08', 'Almacén A')
# (486, 'Objeto486', 'Jardín', 286.53, 15, 'Proveedor3', '2023-10-18', 'Almacén A')
# (487, 'Objeto487', 'Hogar', 233.3, 37, 'Proveedor1', '2023-07-14', 'Almacén A')
# (488, 'Objeto488', 'Hogar', 344.21, 92, 'Proveedor1', '2023-04-27', 'Almacén A')
# (489, 'Producto489', 'Jardín', 165.69, 86, 'Proveedor3', '2023-08-05', 'Almacén B')
# (490, 'Objeto490', 'Hogar', 240.53, 7, 'Proveedor3', '2023-11-04', 'Almacén B')
# (491, 'Objeto491', 'Deportes', 130.02, 84, 'Proveedor3', '2023-11-28', 'Almacén B')
# (492, 'Artículo492', 'Moda', 270.61, 71, 'Proveedor3', '2023-04-07', 'Almacén C')
# (493, 'Objeto493', 'Hogar', 195.85, 97, 'Proveedor3', '2023-02-18', 'Almacén C')
# (494, 'Objeto494', 'Jardín', 185.49, 79, 'Proveedor3', '2023-07-08', 'Almacén C')
# (495, 'Artículo495', 'Electrónica', 461.3, 30, 'Proveedor1', '2023-12-17', 'Almacén B')
# (496, 'Artículo496', 'Jardín', 70.43, 79, 'Proveedor3', '2023-10-22', 'Almacén A')
# (497, 'Producto497', 'Deportes', 230.06, 70, 'Proveedor1', '2023-01-02', 'Almacén A')
# (498, 'Producto498', 'Deportes', 105.69, 27, 'Proveedor3', '2023-02-12', 'Almacén A')
# (499, 'Objeto499', 'Moda', 318.8, 81, 'Proveedor2', '2023-07-02', 'Almacén A')
# (500, 'Objeto500', 'Deportes', 44.03, 48, 'Proveedor1', '2023-05-13', 'Almacén A')
# (501, 'Objeto501', 'Moda', 311.13, 32, 'Proveedor3', '2023-06-23', 'Almacén C')
# (502, 'Artículo502', 'Hogar', 489.96, 54, 'Proveedor2', '2023-02-28', 'Almacén C')
# (503, 'Objeto503', 'Electrónica', 419.45, 5, 'Proveedor3', '2023-11-04', 'Almacén A')
# (504, 'Artículo504', 'Hogar', 188.16, 23, 'Proveedor1', '2023-11-21', 'Almacén C')
# (505, 'Producto505', 'Moda', 408.51, 46, 'Proveedor1', '2023-09-02', 'Almacén A')
# (506, 'Producto506', 'Hogar', 82.94, 2, 'Proveedor2', '2023-10-27', 'Almacén C')
# (507, 'Artículo507', 'Jardín', 425.26, 53, 'Proveedor2', '2023-03-12', 'Almacén B')
# (508, 'Producto508', 'Deportes', 315.3, 41, 'Proveedor2', '2023-07-15', 'Almacén B')
# (509, 'Objeto509', 'Hogar', 21.35, 31, 'Proveedor3', '2023-02-02', 'Almacén A')
# (510, 'Objeto510', 'Electrónica', 435.18, 11, 'Proveedor1', '2023-11-28', 'Almacén C')
# (511, 'Producto511', 'Moda', 94.74, 84, 'Proveedor1', '2023-02-04', 'Almacén A')
# (512, 'Artículo512', 'Jardín', 109.11, 58, 'Proveedor1', '2023-03-08', 'Almacén B')
# (513, 'Objeto513', 'Electrónica', 421.15, 17, 'Proveedor1', '2023-06-15', 'Almacén C')
# (514, 'Artículo514', 'Jardín', 140.65, 54, 'Proveedor2', '2023-12-23', 'Almacén C')
# (515, 'Artículo515', 'Deportes', 75.75, 79, 'Proveedor1', '2023-09-26', 'Almacén C')
# (516, 'Artículo516', 'Deportes', 405.56, 13, 'Proveedor2', '2023-06-25', 'Almacén C')
# (517, 'Producto517', 'Electrónica', 94.84, 51, 'Proveedor2', '2023-06-12', 'Almacén C')
# (518, 'Objeto518', 'Jardín', 189.24, 85, 'Proveedor1', '2023-12-18', 'Almacén C')
# (519, 'Producto519', 'Deportes', 29.21, 100, 'Proveedor1', '2023-02-12', 'Almacén B')
# (520, 'Producto520', 'Hogar', 105.29, 49, 'Proveedor1', '2023-02-06', 'Almacén A')
# (521, 'Artículo521', 'Moda', 57.39, 59, 'Proveedor2', '2023-11-28', 'Almacén A')
# (522, 'Objeto522', 'Hogar', 492.64, 55, 'Proveedor1', '2023-01-15', 'Almacén B')
# (523, 'Artículo523', 'Electrónica', 92.64, 99, 'Proveedor3', '2023-02-20', 'Almacén B')
# (524, 'Objeto524', 'Deportes', 307.86, 81, 'Proveedor2', '2023-04-08', 'Almacén B')
# (525, 'Artículo525', 'Electrónica', 293.23, 54, 'Proveedor2', '2023-04-26', 'Almacén B')
# (526, 'Objeto526', 'Jardín', 490.71, 23, 'Proveedor3', '2023-02-02', 'Almacén A')
# (527, 'Objeto527', 'Electrónica', 364.53, 24, 'Proveedor3', '2023-03-04', 'Almacén B')
# (528, 'Producto528', 'Moda', 234.37, 70, 'Proveedor2', '2023-12-21', 'Almacén A')
# (529, 'Producto529', 'Deportes', 162.63, 44, 'Proveedor2', '2023-04-22', 'Almacén B')
# (530, 'Objeto530', 'Electrónica', 24.11, 61, 'Proveedor1', '2023-01-14', 'Almacén B')
# (531, 'Producto531', 'Hogar', 316.75, 45, 'Proveedor3', '2023-01-27', 'Almacén C')
# (532, 'Objeto532', 'Electrónica', 432.47, 18, 'Proveedor3', '2023-07-04', 'Almacén B')
# (533, 'Artículo533', 'Hogar', 455.43, 69, 'Proveedor1', '2023-09-09', 'Almacén C')
# (534, 'Artículo534', 'Jardín', 197.32, 91, 'Proveedor3', '2023-05-18', 'Almacén C')
# (535, 'Artículo535', 'Electrónica', 297.65, 29, 'Proveedor1', '2023-05-25', 'Almacén A')
# (536, 'Objeto536', 'Deportes', 386.67, 6, 'Proveedor2', '2023-06-09', 'Almacén A')
# (537, 'Objeto537', 'Hogar', 436.35, 90, 'Proveedor2', '2023-03-13', 'Almacén B')
# (538, 'Artículo538', 'Deportes', 63.16, 96, 'Proveedor2', '2023-10-24', 'Almacén B')
# (539, 'Producto539', 'Moda', 483.27, 20, 'Proveedor3', '2023-02-27', 'Almacén C')
# (540, 'Artículo540', 'Moda', 439.64, 18, 'Proveedor2', '2023-09-17', 'Almacén B')
# (541, 'Objeto541', 'Jardín', 110.1, 19, 'Proveedor1', '2023-01-18', 'Almacén C')
# (542, 'Objeto542', 'Hogar', 469.47, 94, 'Proveedor1', '2023-04-07', 'Almacén A')
# (543, 'Producto543', 'Moda', 310.18, 27, 'Proveedor2', '2023-04-06', 'Almacén C')
# (544, 'Objeto544', 'Deportes', 319.55, 50, 'Proveedor1', '2023-11-11', 'Almacén B')
# (545, 'Objeto545', 'Moda', 477.84, 61, 'Proveedor1', '2023-04-16', 'Almacén B')
# (546, 'Objeto546', 'Electrónica', 215.13, 51, 'Proveedor2', '2023-11-07', 'Almacén C')
# (547, 'Producto547', 'Moda', 79.57, 74, 'Proveedor1', '2023-06-26', 'Almacén C')
# (548, 'Producto548', 'Jardín', 439.54, 85, 'Proveedor2', '2023-12-12', 'Almacén C')
# (549, 'Artículo549', 'Moda', 125.21, 16, 'Proveedor2', '2023-05-02', 'Almacén C')
# (550, 'Artículo550', 'Hogar', 30.11, 57, 'Proveedor1', '2023-10-18', 'Almacén B')
# (551, 'Artículo551', 'Electrónica', 227.68, 74, 'Proveedor3', '2023-01-24', 'Almacén A')
# (552, 'Artículo552', 'Electrónica', 136.88, 16, 'Proveedor3', '2023-07-15', 'Almacén A')
# (553, 'Artículo553', 'Hogar', 464.88, 64, 'Proveedor3', '2023-07-02', 'Almacén B')
# (554, 'Producto554', 'Electrónica', 24.59, 72, 'Proveedor2', '2023-05-05', 'Almacén B')
# (555, 'Artículo555', 'Jardín', 486.79, 13, 'Proveedor2', '2023-12-27', 'Almacén A')
# (556, 'Producto556', 'Deportes', 382.49, 76, 'Proveedor3', '2023-08-04', 'Almacén A')
# (557, 'Artículo557', 'Jardín', 383.16, 29, 'Proveedor2', '2023-01-04', 'Almacén C')
# (558, 'Producto558', 'Deportes', 421.2, 27, 'Proveedor1', '2023-03-03', 'Almacén A')
# (559, 'Artículo559', 'Hogar', 386.35, 23, 'Proveedor2', '2023-09-08', 'Almacén C')
# (560, 'Artículo560', 'Deportes', 320.75, 28, 'Proveedor2', '2023-09-27', 'Almacén C')
# (561, 'Producto561', 'Jardín', 392.01, 12, 'Proveedor2', '2023-03-06', 'Almacén C')
# (562, 'Artículo562', 'Moda', 102.53, 27, 'Proveedor1', '2023-11-25', 'Almacén A')
# (563, 'Producto563', 'Electrónica', 54.33, 12, 'Proveedor3', '2023-01-05', 'Almacén C')
# (564, 'Objeto564', 'Jardín', 129.54, 87, 'Proveedor3', '2023-02-26', 'Almacén A')
# (565, 'Producto565', 'Electrónica', 244.59, 77, 'Proveedor1', '2023-10-07', 'Almacén C')
# (566, 'Artículo566', 'Electrónica', 293.19, 26, 'Proveedor1', '2023-05-06', 'Almacén C')
# (567, 'Producto567', 'Moda', 282.37, 82, 'Proveedor2', '2023-03-03', 'Almacén C')
# (568, 'Objeto568', 'Moda', 213.2, 74, 'Proveedor3', '2023-03-09', 'Almacén B')
# (569, 'Objeto569', 'Electrónica', 286.51, 71, 'Proveedor2', '2023-05-12', 'Almacén A')
# (570, 'Artículo570', 'Deportes', 301.04, 83, 'Proveedor3', '2023-11-05', 'Almacén A')
# (571, 'Producto571', 'Hogar', 376.62, 80, 'Proveedor3', '2023-08-26', 'Almacén C')
# (572, 'Artículo572', 'Jardín', 290.35, 70, 'Proveedor1', '2023-10-03', 'Almacén C')
# (573, 'Objeto573', 'Electrónica', 89.02, 80, 'Proveedor1', '2023-02-08', 'Almacén C')
# (574, 'Artículo574', 'Hogar', 246.12, 67, 'Proveedor1', '2023-06-23', 'Almacén C')
# (575, 'Producto575', 'Moda', 105.85, 38, 'Proveedor2', '2023-06-16', 'Almacén C')
# ...
# (9815, 'Artículo9815', 'Jardín', 469.06, 22, 'Proveedor3', '2023-02-15', 'Almacén A')
# (9816, 'Artículo9816', 'Electrónica', 372.35, 53, 'Proveedor3', '2023-09-02', 'Almacén A')
# (9817, 'Objeto9817', 'Electrónica', 285.99, 12, 'Proveedor2', '2023-04-18', 'Almacén B')
# (9818, 'Producto9818', 'Deportes', 316.95, 81, 'Proveedor1', '2023-05-17', 'Almacén A')
# (9819, 'Artículo9819', 'Hogar', 195.17, 91, 'Proveedor2', '2023-03-01', 'Almacén A')
# (9820, 'Objeto9820', 'Hogar', 257.99, 84, 'Proveedor1', '2023-06-16', 'Almacén A')
# (9821, 'Objeto9821', 'Jardín', 302.8, 63, 'Proveedor2', '2023-01-03', 'Almacén A')
# (9822, 'Artículo9822', 'Moda', 289.2, 40, 'Proveedor3', '2023-10-07', 'Almacén C')
# (9823, 'Objeto9823', 'Hogar', 317.52, 96, 'Proveedor1', '2023-07-24', 'Almacén A')
# (9824, 'Producto9824', 'Jardín', 314.44, 74, 'Proveedor3', '2023-04-17', 'Almacén C')
# (9825, 'Producto9825', 'Electrónica', 409.87, 59, 'Proveedor3', '2023-06-16', 'Almacén B')
# (9826, 'Artículo9826', 'Deportes', 251.26, 71, 'Proveedor3', '2023-02-01', 'Almacén A')
# (9827, 'Objeto9827', 'Hogar', 127.98, 23, 'Proveedor2', '2023-07-05', 'Almacén B')
# (9828, 'Objeto9828', 'Moda', 77.18, 10, 'Proveedor3', '2023-12-08', 'Almacén C')
# (9829, 'Producto9829', 'Hogar', 223.18, 82, 'Proveedor3', '2023-12-09', 'Almacén A')
# (9830, 'Producto9830', 'Electrónica', 432.91, 38, 'Proveedor1', '2023-03-10', 'Almacén C')
# (9831, 'Producto9831', 'Jardín', 73.3, 51, 'Proveedor2', '2023-08-12', 'Almacén C')
# (9832, 'Artículo9832', 'Hogar', 270.32, 88, 'Proveedor1', '2023-09-21', 'Almacén B')
# (9833, 'Producto9833', 'Electrónica', 124.63, 18, 'Proveedor2', '2023-11-27', 'Almacén A')
# (9834, 'Objeto9834', 'Hogar', 402.96, 100, 'Proveedor1', '2023-10-24', 'Almacén C')
# (9835, 'Objeto9835', 'Electrónica', 131.27, 85, 'Proveedor2', '2023-03-04', 'Almacén B')
# (9836, 'Objeto9836', 'Jardín', 315.81, 56, 'Proveedor2', '2023-02-06', 'Almacén C')
# (9837, 'Artículo9837', 'Hogar', 342.38, 35, 'Proveedor3', '2023-03-24', 'Almacén B')
# (9838, 'Artículo9838', 'Deportes', 293.18, 65, 'Proveedor3', '2023-02-22', 'Almacén C')
# (9839, 'Producto9839', 'Hogar', 197.99, 70, 'Proveedor1', '2023-03-03', 'Almacén B')
# (9840, 'Objeto9840', 'Moda', 331.39, 24, 'Proveedor1', '2023-08-08', 'Almacén A')
# (9841, 'Artículo9841', 'Jardín', 372.26, 31, 'Proveedor2', '2023-12-03', 'Almacén A')
# (9842, 'Artículo9842', 'Electrónica', 188.28, 36, 'Proveedor3', '2023-09-24', 'Almacén B')
# (9843, 'Objeto9843', 'Jardín', 347.16, 30, 'Proveedor2', '2023-12-11', 'Almacén A')
# (9844, 'Objeto9844', 'Hogar', 203.34, 65, 'Proveedor1', '2023-09-05', 'Almacén A')
# (9845, 'Producto9845', 'Deportes', 416.53, 20, 'Proveedor3', '2023-03-11', 'Almacén B')
# (9846, 'Artículo9846', 'Electrónica', 264.97, 34, 'Proveedor2', '2023-12-15', 'Almacén C')
# (9847, 'Artículo9847', 'Deportes', 283.19, 96, 'Proveedor2', '2023-06-13', 'Almacén A')
# (9848, 'Artículo9848', 'Jardín', 178.93, 31, 'Proveedor2', '2023-06-28', 'Almacén B')
# (9849, 'Artículo9849', 'Deportes', 162.03, 98, 'Proveedor3', '2023-01-27', 'Almacén A')
# (9850, 'Producto9850', 'Deportes', 466.39, 33, 'Proveedor3', '2023-06-07', 'Almacén A')
# (9851, 'Producto9851', 'Moda', 12.93, 33, 'Proveedor2', '2023-11-22', 'Almacén A')
# (9852, 'Objeto9852', 'Hogar', 496.57, 74, 'Proveedor2', '2023-02-02', 'Almacén A')
# (9853, 'Artículo9853', 'Moda', 18.18, 46, 'Proveedor1', '2023-09-22', 'Almacén C')
# (9854, 'Producto9854', 'Jardín', 58.19, 91, 'Proveedor2', '2023-07-07', 'Almacén A')
# (9855, 'Artículo9855', 'Jardín', 286.03, 69, 'Proveedor1', '2023-09-21', 'Almacén A')
# (9856, 'Producto9856', 'Electrónica', 304.89, 30, 'Proveedor1', '2023-09-13', 'Almacén C')
# (9857, 'Producto9857', 'Hogar', 282.82, 38, 'Proveedor3', '2023-05-13', 'Almacén B')
# (9858, 'Artículo9858', 'Deportes', 456.65, 66, 'Proveedor2', '2023-10-25', 'Almacén C')
# (9859, 'Producto9859', 'Electrónica', 196.09, 39, 'Proveedor3', '2023-01-09', 'Almacén B')
# (9860, 'Artículo9860', 'Moda', 97.09, 89, 'Proveedor1', '2023-02-20', 'Almacén B')
# (9861, 'Producto9861', 'Deportes', 222.9, 71, 'Proveedor1', '2023-07-23', 'Almacén B')
# (9862, 'Objeto9862', 'Electrónica', 33.6, 61, 'Proveedor1', '2023-06-15', 'Almacén B')
# (9863, 'Artículo9863', 'Electrónica', 339.8, 70, 'Proveedor1', '2023-01-25', 'Almacén A')
# (9864, 'Producto9864', 'Electrónica', 43.38, 48, 'Proveedor2', '2023-03-27', 'Almacén A')
# (9865, 'Objeto9865', 'Electrónica', 136.57, 6, 'Proveedor1', '2023-08-27', 'Almacén C')
# (9866, 'Artículo9866', 'Hogar', 357.55, 48, 'Proveedor2', '2023-09-06', 'Almacén A')
# (9867, 'Producto9867', 'Deportes', 488.86, 58, 'Proveedor2', '2023-07-01', 'Almacén A')
# (9868, 'Producto9868', 'Deportes', 425.79, 77, 'Proveedor2', '2023-09-07', 'Almacén A')
# (9869, 'Objeto9869', 'Electrónica', 289.24, 59, 'Proveedor2', '2023-02-25', 'Almacén C')
# (9870, 'Producto9870', 'Hogar', 220.92, 8, 'Proveedor2', '2023-10-25', 'Almacén C')
# (9871, 'Objeto9871', 'Moda', 444.19, 73, 'Proveedor3', '2023-02-13', 'Almacén C')
# (9872, 'Artículo9872', 'Hogar', 131.66, 77, 'Proveedor1', '2023-11-24', 'Almacén B')
# (9873, 'Objeto9873', 'Electrónica', 283.47, 92, 'Proveedor3', '2023-09-16', 'Almacén A')
# (9874, 'Objeto9874', 'Electrónica', 425.07, 63, 'Proveedor3', '2023-06-08', 'Almacén B')
# (9875, 'Artículo9875', 'Jardín', 221.8, 98, 'Proveedor3', '2023-02-24', 'Almacén A')
# (9876, 'Artículo9876', 'Hogar', 224.8, 10, 'Proveedor3', '2023-02-17', 'Almacén A')
# (9877, 'Artículo9877', 'Hogar', 73.5, 88, 'Proveedor3', '2023-11-11', 'Almacén C')
# (9878, 'Artículo9878', 'Electrónica', 314.97, 64, 'Proveedor1', '2023-11-26', 'Almacén B')
# (9879, 'Objeto9879', 'Hogar', 29.23, 96, 'Proveedor2', '2023-04-04', 'Almacén C')
# (9880, 'Producto9880', 'Electrónica', 307.84, 15, 'Proveedor1', '2023-03-18', 'Almacén C')
# (9881, 'Objeto9881', 'Hogar', 329.61, 34, 'Proveedor2', '2023-11-12', 'Almacén A')
# (9882, 'Artículo9882', 'Deportes', 341.23, 96, 'Proveedor1', '2023-04-12', 'Almacén B')
# (9883, 'Artículo9883', 'Hogar', 226.04, 54, 'Proveedor3', '2023-12-09', 'Almacén C')
# (9884, 'Producto9884', 'Deportes', 109.22, 17, 'Proveedor1', '2023-02-23', 'Almacén A')
# (9885, 'Objeto9885', 'Hogar', 51.2, 45, 'Proveedor3', '2023-02-28', 'Almacén B')
# (9886, 'Objeto9886', 'Jardín', 62.91, 54, 'Proveedor2', '2023-02-05', 'Almacén C')
# (9887, 'Artículo9887', 'Moda', 174.72, 21, 'Proveedor2', '2023-05-22', 'Almacén B')
# (9888, 'Artículo9888', 'Moda', 53.94, 49, 'Proveedor3', '2023-08-02', 'Almacén A')
# (9889, 'Artículo9889', 'Deportes', 240.1, 77, 'Proveedor3', '2023-04-24', 'Almacén B')
# (9890, 'Artículo9890', 'Electrónica', 431.1, 1, 'Proveedor1', '2023-01-28', 'Almacén B')
# (9891, 'Objeto9891', 'Deportes', 78.83, 25, 'Proveedor3', '2023-06-26', 'Almacén C')
# (9892, 'Producto9892', 'Moda', 268.9, 11, 'Proveedor1', '2023-10-16', 'Almacén C')
# (9893, 'Producto9893', 'Jardín', 307.96, 53, 'Proveedor1', '2023-06-27', 'Almacén C')
# (9894, 'Objeto9894', 'Deportes', 191.7, 80, 'Proveedor1', '2023-01-11', 'Almacén A')
# (9895, 'Producto9895', 'Moda', 395.67, 23, 'Proveedor3', '2023-07-26', 'Almacén A')
# (9896, 'Artículo9896', 'Electrónica', 156.3, 22, 'Proveedor2', '2023-04-05', 'Almacén B')
# (9897, 'Producto9897', 'Electrónica', 228, 5, 'Proveedor1', '2023-09-25', 'Almacén A')
# (9898, 'Producto9898', 'Moda', 67.31, 98, 'Proveedor2', '2023-12-04', 'Almacén A')
# (9899, 'Artículo9899', 'Deportes', 48.63, 9, 'Proveedor1', '2023-07-09', 'Almacén C')
# (9900, 'Artículo9900', 'Electrónica', 80.5, 51, 'Proveedor2', '2023-03-05', 'Almacén C')
# (9901, 'Artículo9901', 'Hogar', 26.12, 16, 'Proveedor1', '2023-01-05', 'Almacén A')
# (9902, 'Objeto9902', 'Moda', 86.5, 100, 'Proveedor2', '2023-12-03', 'Almacén C')
# (9903, 'Objeto9903', 'Electrónica', 348.34, 62, 'Proveedor3', '2023-12-08', 'Almacén B')
# (9904, 'Artículo9904', 'Hogar', 499.11, 7, 'Proveedor3', '2023-03-20', 'Almacén A')
# (9905, 'Producto9905', 'Hogar', 145.94, 58, 'Proveedor2', '2023-07-15', 'Almacén A')
# (9906, 'Objeto9906', 'Moda', 307.1, 37, 'Proveedor1', '2023-05-23', 'Almacén B')
# (9907, 'Artículo9907', 'Electrónica', 177.55, 83, 'Proveedor2', '2023-04-03', 'Almacén C')
# (9908, 'Objeto9908', 'Jardín', 326.94, 33, 'Proveedor3', '2023-07-05', 'Almacén A')
# (9909, 'Artículo9909', 'Electrónica', 114.73, 86, 'Proveedor1', '2023-07-22', 'Almacén B')
# (9910, 'Objeto9910', 'Moda', 360.63, 48, 'Proveedor1', '2023-08-02', 'Almacén C')
# (9911, 'Objeto9911', 'Moda', 144.12, 91, 'Proveedor1', '2023-10-24', 'Almacén A')
# (9912, 'Artículo9912', 'Moda', 69.51, 77, 'Proveedor2', '2023-02-06', 'Almacén C')
# (9913, 'Producto9913', 'Moda', 194.77, 86, 'Proveedor2', '2023-10-23', 'Almacén A')
# (9914, 'Objeto9914', 'Hogar', 65.59, 2, 'Proveedor3', '2023-06-18', 'Almacén C')
# (9915, 'Producto9915', 'Jardín', 10.16, 93, 'Proveedor1', '2023-01-12', 'Almacén B')
# (9916, 'Objeto9916', 'Electrónica', 72.72, 10, 'Proveedor1', '2023-05-09', 'Almacén A')
# (9917, 'Artículo9917', 'Hogar', 122.25, 76, 'Proveedor1', '2023-11-13', 'Almacén A')
# (9918, 'Artículo9918', 'Moda', 70.45, 86, 'Proveedor2', '2023-08-17', 'Almacén C')
# (9919, 'Objeto9919', 'Moda', 332.94, 43, 'Proveedor3', '2023-05-18', 'Almacén C')
# (9920, 'Objeto9920', 'Electrónica', 162.07, 4, 'Proveedor2', '2023-10-21', 'Almacén C')
# (9921, 'Artículo9921', 'Electrónica', 327.31, 68, 'Proveedor1', '2023-10-08', 'Almacén C')
# (9922, 'Producto9922', 'Moda', 423.32, 48, 'Proveedor3', '2023-04-20', 'Almacén C')
# (9923, 'Producto9923', 'Deportes', 262.12, 43, 'Proveedor2', '2023-11-05', 'Almacén C')
# (9924, 'Producto9924', 'Hogar', 48.03, 24, 'Proveedor2', '2023-02-22', 'Almacén B')
# (9925, 'Producto9925', 'Moda', 386.3, 33, 'Proveedor2', '2023-02-07', 'Almacén A')
# (9926, 'Objeto9926', 'Deportes', 205.19, 23, 'Proveedor3', '2023-08-05', 'Almacén C')
# (9927, 'Objeto9927', 'Moda', 422.96, 76, 'Proveedor1', '2023-04-20', 'Almacén C')
# (9928, 'Artículo9928', 'Jardín', 206.14, 52, 'Proveedor3', '2023-12-18', 'Almacén A')
# (9929, 'Artículo9929', 'Moda', 58.97, 37, 'Proveedor3', '2023-04-23', 'Almacén B')
# (9930, 'Objeto9930', 'Jardín', 463.83, 68, 'Proveedor1', '2023-11-09', 'Almacén B')
# (9931, 'Artículo9931', 'Moda', 312.18, 64, 'Proveedor1', '2023-02-24', 'Almacén A')
# (9932, 'Producto9932', 'Jardín', 212.45, 41, 'Proveedor3', '2023-08-07', 'Almacén C')
# (9933, 'Producto9933', 'Electrónica', 452.54, 84, 'Proveedor3', '2023-12-03', 'Almacén A')
# (9934, 'Producto9934', 'Jardín', 294.56, 19, 'Proveedor3', '2023-01-06', 'Almacén A')
# (9935, 'Objeto9935', 'Jardín', 345, 65, 'Proveedor3', '2023-02-25', 'Almacén B')
# (9936, 'Artículo9936', 'Deportes', 329.87, 63, 'Proveedor3', '2023-01-19', 'Almacén A')
# (9937, 'Objeto9937', 'Deportes', 225.56, 52, 'Proveedor1', '2023-01-27', 'Almacén B')
# (9938, 'Objeto9938', 'Jardín', 63.75, 32, 'Proveedor3', '2023-09-14', 'Almacén B')
# (9939, 'Artículo9939', 'Electrónica', 169.86, 34, 'Proveedor2', '2023-02-08', 'Almacén B')
# (9940, 'Artículo9940', 'Deportes', 250.26, 37, 'Proveedor1', '2023-07-01', 'Almacén A')
# (9941, 'Producto9941', 'Electrónica', 182.72, 86, 'Proveedor1', '2023-11-15', 'Almacén B')
# (9942, 'Objeto9942', 'Electrónica', 84.47, 75, 'Proveedor2', '2023-05-05', 'Almacén C')
# (9943, 'Producto9943', 'Moda', 136.11, 81, 'Proveedor2', '2023-06-15', 'Almacén C')
# (9944, 'Objeto9944', 'Hogar', 416.45, 87, 'Proveedor2', '2023-04-06', 'Almacén B')
# (9945, 'Producto9945', 'Electrónica', 225.25, 19, 'Proveedor1', '2023-06-18', 'Almacén B')
# (9946, 'Artículo9946', 'Jardín', 160.77, 23, 'Proveedor1', '2023-10-20', 'Almacén C')
# (9947, 'Objeto9947', 'Electrónica', 55.7, 34, 'Proveedor2', '2023-02-09', 'Almacén A')
# (9948, 'Artículo9948', 'Electrónica', 46.42, 68, 'Proveedor2', '2023-07-11', 'Almacén B')
# (9949, 'Artículo9949', 'Deportes', 15.43, 68, 'Proveedor2', '2023-05-04', 'Almacén C')
# (9950, 'Artículo9950', 'Electrónica', 219.17, 23, 'Proveedor1', '2023-01-26', 'Almacén C')
# (9951, 'Producto9951', 'Hogar', 390.46, 54, 'Proveedor3', '2023-08-17', 'Almacén C')
# (9952, 'Objeto9952', 'Deportes', 327.46, 39, 'Proveedor1', '2023-07-25', 'Almacén B')
# (9953, 'Producto9953', 'Moda', 201.17, 51, 'Proveedor3', '2023-12-12', 'Almacén C')
# (9954, 'Producto9954', 'Hogar', 204.01, 75, 'Proveedor3', '2023-05-24', 'Almacén B')
# (9955, 'Producto9955', 'Moda', 304.29, 70, 'Proveedor3', '2023-10-08', 'Almacén A')
# (9956, 'Producto9956', 'Jardín', 95.25, 78, 'Proveedor3', '2023-09-18', 'Almacén A')
# (9957, 'Producto9957', 'Deportes', 329.84, 10, 'Proveedor1', '2023-11-28', 'Almacén A')
# (9958, 'Producto9958', 'Moda', 262.22, 31, 'Proveedor3', '2023-11-10', 'Almacén B')
# (9959, 'Producto9959', 'Deportes', 60.71, 82, 'Proveedor2', '2023-05-20', 'Almacén A')
# (9960, 'Objeto9960', 'Moda', 63.38, 58, 'Proveedor1', '2023-07-03', 'Almacén B')
# (9961, 'Artículo9961', 'Hogar', 234.36, 42, 'Proveedor2', '2023-08-02', 'Almacén B')
# (9962, 'Producto9962', 'Jardín', 274.36, 6, 'Proveedor3', '2023-03-12', 'Almacén A')
# (9963, 'Producto9963', 'Hogar', 169.03, 44, 'Proveedor3', '2023-01-04', 'Almacén C')
# (9964, 'Objeto9964', 'Moda', 80.15, 92, 'Proveedor2', '2023-01-13', 'Almacén B')
# (9965, 'Producto9965', 'Hogar', 350.31, 54, 'Proveedor1', '2023-04-03', 'Almacén C')
# (9966, 'Objeto9966', 'Jardín', 421.12, 4, 'Proveedor3', '2023-11-28', 'Almacén C')
# (9967, 'Artículo9967', 'Deportes', 266.65, 32, 'Proveedor1', '2023-10-05', 'Almacén C')
# (9968, 'Producto9968', 'Hogar', 290.42, 67, 'Proveedor2', '2023-03-21', 'Almacén B')
# (9969, 'Artículo9969', 'Deportes', 462.55, 7, 'Proveedor3', '2023-02-16', 'Almacén C')
# (9970, 'Artículo9970', 'Deportes', 300.96, 9, 'Proveedor3', '2023-05-18', 'Almacén B')
# (9971, 'Producto9971', 'Hogar', 288.1, 96, 'Proveedor3', '2023-08-16', 'Almacén C')
# (9972, 'Producto9972', 'Hogar', 388.4, 35, 'Proveedor2', '2023-08-22', 'Almacén B')
# (9973, 'Producto9973', 'Jardín', 112.21, 93, 'Proveedor3', '2023-09-09', 'Almacén B')
# (9974, 'Producto9974', 'Deportes', 205.35, 23, 'Proveedor3', '2023-01-27', 'Almacén C')
# (9975, 'Objeto9975', 'Deportes', 495.5, 41, 'Proveedor1', '2023-12-12', 'Almacén C')
# (9976, 'Artículo9976', 'Hogar', 21.94, 77, 'Proveedor1', '2023-03-10', 'Almacén C')
# (9977, 'Producto9977', 'Moda', 226.41, 91, 'Proveedor1', '2023-02-13', 'Almacén C')
# (9978, 'Producto9978', 'Moda', 204.92, 92, 'Proveedor1', '2023-08-01', 'Almacén B')
# (9979, 'Objeto9979', 'Hogar', 65.22, 23, 'Proveedor2', '2023-10-26', 'Almacén A')
# (9980, 'Artículo9980', 'Hogar', 474.88, 9, 'Proveedor1', '2023-10-12', 'Almacén A')
# (9981, 'Objeto9981', 'Hogar', 418.96, 95, 'Proveedor3', '2023-07-13', 'Almacén C')
# (9982, 'Artículo9982', 'Deportes', 240.65, 11, 'Proveedor3', '2023-03-11', 'Almacén B')
# (9983, 'Artículo9983', 'Hogar', 422.83, 59, 'Proveedor1', '2023-07-02', 'Almacén B')
# (9984, 'Objeto9984', 'Hogar', 216.78, 57, 'Proveedor3', '2023-09-25', 'Almacén C')
# (9985, 'Artículo9985', 'Electrónica', 51.7, 43, 'Proveedor2', '2023-03-20', 'Almacén A')
# (9986, 'Producto9986', 'Electrónica', 18.9, 37, 'Proveedor3', '2023-12-20', 'Almacén A')
# (9987, 'Objeto9987', 'Jardín', 451.15, 95, 'Proveedor1', '2023-04-06', 'Almacén C')
# (9988, 'Producto9988', 'Deportes', 73.52, 51, 'Proveedor3', '2023-03-21', 'Almacén B')
# (9989, 'Artículo9989', 'Jardín', 281.62, 54, 'Proveedor1', '2023-03-17', 'Almacén A')
# (9990, 'Objeto9990', 'Hogar', 417.37, 47, 'Proveedor1', '2023-12-19', 'Almacén C')
# (9991, 'Artículo9991', 'Jardín', 303.68, 91, 'Proveedor2', '2023-08-23', 'Almacén C')
# (9992, 'Producto9992', 'Deportes', 370.31, 87, 'Proveedor1', '2023-08-15', 'Almacén B')
# (9993, 'Artículo9993', 'Jardín', 222.19, 27, 'Proveedor3', '2023-12-08', 'Almacén B')
# (9994, 'Producto9994', 'Moda', 275.4, 4, 'Proveedor2', '2023-12-06', 'Almacén B')
# (9995, 'Artículo9995', 'Electrónica', 231.88, 81, 'Proveedor1', '2023-05-14', 'Almacén A')
# (9996, 'Objeto9996', 'Hogar', 331.03, 16, 'Proveedor2', '2023-01-16', 'Almacén B')
# (9997, 'Objeto9997', 'Moda', 229.45, 5, 'Proveedor3', '2023-03-19', 'Almacén C')
# (9998, 'Producto9998', 'Moda', 324.91, 75, 'Proveedor1', '2023-06-01', 'Almacén A')
# (9999, 'Artículo9999', 'Deportes', 167.85, 18, 'Proveedor1', '2023-11-17', 'Almacén B')
# (10000, 'Objeto10000', 'Deportes', 14.89, 12, 'Proveedor1', '2023-09-13', 'Almacén C')

# %% [markdown]
# ##Realizar consulta y transferir a dataframe

# %% [markdown]
# A diferencia del anterior codigo, este se muestra de manera mas ordenada.

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#         id        nombre    categoria  precio  cantidad   proveedor  \
# 0       16    Artículo16       Jardín  462.53         6  Proveedor2
# 1       23      Objeto23  Electrónica  489.34        73  Proveedor3
# 2       31      Objeto31     Deportes  498.32        60  Proveedor3
# 3       51    Producto51       Jardín  495.95        73  Proveedor1
# 4       57    Producto57     Deportes  490.78        58  Proveedor3
# ...    ...           ...          ...     ...       ...         ...
# 1046  9933  Producto9933  Electrónica  452.54        84  Proveedor3
# 1047  9969  Artículo9969     Deportes  462.55         7  Proveedor3
# 1048  9975    Objeto9975     Deportes  495.50        41  Proveedor1
# 1049  9980  Artículo9980        Hogar  474.88         9  Proveedor1
# 1050  9987    Objeto9987       Jardín  451.15        95  Proveedor1
#
#      fecha_ingreso  ubicacion
# 0       2023-11-23  Almacén A
# 1       2023-11-26  Almacén A
# 2       2023-07-12  Almacén C
# 3       2023-04-17  Almacén A
# 4       2023-12-24  Almacén C
# ...            ...        ...
# 1046    2023-12-03  Almacén A
# 1047    2023-02-16  Almacén C
# 1048    2023-12-12  Almacén C
# 1049    2023-10-12  Almacén A
# 1050    2023-04-06  Almacén C
#
# [1051 rows x 8 columns]

# %%
df_productos.head()
# Out:
#    id      nombre    categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0  16  Artículo16       Jardín  462.53         6  Proveedor2    2023-11-23
# 1  23    Objeto23  Electrónica  489.34        73  Proveedor3    2023-11-26
# 2  31    Objeto31     Deportes  498.32        60  Proveedor3    2023-07-12
# 3  51  Producto51       Jardín  495.95        73  Proveedor1    2023-04-17
# 4  57  Producto57     Deportes  490.78        58  Proveedor3    2023-12-24
#
#    ubicacion
# 0  Almacén A
# 1  Almacén A
# 2  Almacén C
# 3  Almacén A
# 4  Almacén C

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 480 OR cantidad > 5"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#          id        nombre    categoria  precio  cantidad   proveedor  \
# 0         1       Objeto1       Jardín  420.37        62  Proveedor1
# 1         2     Producto2         Moda  348.83        42  Proveedor3
# 2         3     Artículo3         Moda  308.65        76  Proveedor2
# 3         4       Objeto4        Hogar  201.76        91  Proveedor2
# 4         5       Objeto5        Hogar  235.66        85  Proveedor1
# ...     ...           ...          ...     ...       ...         ...
# 9505   9995  Artículo9995  Electrónica  231.88        81  Proveedor1
# 9506   9996    Objeto9996        Hogar  331.03        16  Proveedor2
# 9507   9998  Producto9998         Moda  324.91        75  Proveedor1
# 9508   9999  Artículo9999     Deportes  167.85        18  Proveedor1
# 9509  10000   Objeto10000     Deportes   14.89        12  Proveedor1
#
#      fecha_ingreso  ubicacion
# 0       2023-09-17  Almacén C
# 1       2023-02-21  Almacén C
# 2       2023-03-25  Almacén B
# 3       2023-11-21  Almacén C
# 4       2023-10-19  Almacén A
# ...            ...        ...
# 9505    2023-05-14  Almacén A
# 9506    2023-01-16  Almacén B
# 9507    2023-06-01  Almacén A
# 9508    2023-11-17  Almacén B
# 9509    2023-09-13  Almacén C
#
# [9510 rows x 8 columns]

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-06 15:56:53.009228  Almacén B
# 1 2025-03-11 15:56:53.009279  Almacén C
# 2 2024-12-17 15:56:53.009295  Almacén B
# 3 2025-08-14 15:56:53.009307  Almacén A
# 4 2024-11-30 15:56:53.009317  Almacén A

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-06 15:56:53.009  Almacén B
# 1 2025-03-11 15:56:53.009  Almacén C
# 2 2024-12-17 15:56:53.009  Almacén B
# 3 2025-08-14 15:56:53.009  Almacén A
# 4 2024-11-30 15:56:53.009  Almacén A

# %%
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de datos en la DB
for index, row in df.iterrows():
    fecha_ingreso_str = row['Fecha de Ingreso'].strftime('%Y-%m-%d')
    c.execute("""
         INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
         VALUES(?, ?, ?, ?, ?, ?, ?)""",(row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], fecha_ingreso_str, row['Ubicación']))

# # Insersión de datos en la DB
# for index, row in df.iterrows():
#     c.executemany("""
#         INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#         VALUES(?, ?, ?, ?, ?, ?,)""",
#         [row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']])

# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ¡Datos importados exitosamente!

# %%
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Dupla con los datos
datos_ingreso = []
for index, row in df.iterrows():
    # Convierte Timestamp a string en formato 'YYYY-MM-DD'
    fecha_ingreso_str = row['Fecha de Ingreso'].strftime('%Y-%m-%d')
    datos_ingreso.append((
        row['Nombre'],
        row['Categoría'],
        row['Precio'],
        row['Cantidad'],
        row['Proveedor'],
        fecha_ingreso_str,
        row['Ubicación']
    ))

# Insersión de datos
c.executemany("""
    INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
    VALUES (?, ?, ?, ?, ?, ?, ?)""", datos_ingreso)

# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ¡Datos importados exitosamente!

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Consulta SQL para calcular el valor total por categoría y ordenar
query = """
SELECT
    categoria,
    SUM(precio * cantidad) AS valor_total
FROM
    inventario
GROUP BY
    categoria
ORDER BY
    valor_total DESC;
"""

# Ejecutar la consulta y cargar los resultados en un DataFrame
df_valor_por_categoria = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print("Valor total del inventario por categoría:")
print(df_valor_por_categoria)

# Cerrar la conexión
conn.close()
# Out:
# Valor total del inventario por categoría:
#      categoria  valor_total
# 0     Deportes  52186385.92
# 1         Moda  51976592.82
# 2        Hogar  51631739.15
# 3  Electrónica  51441153.72
# 4       Jardín  51024334.63
